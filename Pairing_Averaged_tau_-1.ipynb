# %% [markdown]
# # **Pairing Averaged**

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection


import Materials_Parameters as mp
from MTI_Discretization import eigenstates_Dirichlet as eigenstates
from MTI_Second_Order import FMTI2_NeumannBC, Change_Basis, Block_Reverse

# parameters
d = 100.; mu = 0.010; Delta = 0.005
# coupling matrices
Gamma = np.matrix([[1,0],[0,1],[1,0],[0,1]])

# %% [markdown]
# ## Finite Magnetization $\Lambda = 20$ meV
#
# We assume here the tunneling coupling to act only on $\tau = +$ states, namely
# $$
#     \gamma_{\sigma\tau}^{\sigma'} = \gamma_\tau \, \delta_{\sigma\sigma'} \,,
#     \qquad
#     \gamma_\tau =
#     \begin{cases}
#         0 & \text{for} \; \tau=+ \,, \\[5pt]
#         %
#         1 & \text{for} \; \tau=- \,.
#     \end{cases}
# $$
#
# #### **Energy Spectrum**

# %%
# lattice
Nlat = 100; d = 100.; dZ = d/(Nlat-1)

egval = []; spinors = []
momentum = np.linspace(-0.15, 0.15, 101)

for k in momentum:

    # eigenstates
    lattice, egv, wf = eigenstates(Nlat=Nlat, dZ=dZ, kx = k, ky = 0., L = 0.020)

    # indices for sorting by absolute value
    idx_sort = np.argsort(egv)
    # sort egval accordingly
    egv = egv[idx_sort]
    # sort wf accordingly
    wf = wf[idx_sort, :, :]   
    
    egval.append(egv); spinors.append(wf) 


egval = np.array(egval)
spinors = np.array(spinors)

print(egval.shape, spinors[0].shape)
# Out:
# (101, 400) (400, 100, 4)

# %%
# figure
fig, ax = plt.subplots(1)
# horizontal line zero energy
ax.axhline(0, ls='--', lw=2, c='red')

n = 50
for idx in range(n):
    
    # index for eigenvalues around zero energy
    iegv = 200 - int(n/2) + idx 

    # plot eigenvalues
    ax.plot(momentum, egval[:,iegv], c='black', lw=2)

ax.set_xlim(-0.1,0.1);
ax.set_ylim(-0.35,0.35);

# %%
from matplotlib.colors import Normalize
from matplotlib.colors import LinearSegmentedColormap

# Define the custom colors
colors = [(0.0, 'green'), (0.4, 'black'), (0.6, 'black'), (1.0, 'orange')]
# Create colormap
cmap = LinearSegmentedColormap.from_list('green_black_orange', colors, N=256)


# figure
fig, ax = plt.subplots(1)
# horizontal line zero energy
ax.axhline(0, ls='--', lw=1.5, c='black')

# number of k values
k_dim = spinors.shape[0]
# normalize between -1 and 1
norm = Normalize(vmin=-1, vmax=1)

# tau_z operator in orbital x spin basis
Tz = np.kron(np.array([[1, 0], [0, -1]]), np.eye(2))


n = 50
for idx in range(n):
    
    # eigenstate index
    iegv = 200 - int(n/2) + idx 

    # get spin z for colors
    tau_z = [np.sum([np.vdot(s, Tz @ s).real for s in spinors[kdx,iegv]]) for kdx in range(k_dim)]
    
    # define x and y arrays for plot
    x,y = momentum, egval[:,iegv]
    
    # create line segments between consecutive points
    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    
    # create LineCollection
    lc = LineCollection(segments, cmap=cmap, array=tau_z[:-1], lw=2, norm=norm)

    # plot line
    line = ax.add_collection(lc)

fig.colorbar(line, ax=ax, label="Orbital $T_z$")

ax.set_xlim(-0.1,0.1);
ax.set_ylim(-0.35,0.35);

#plt.savefig('PPT/MTI_tau_spectrum.pdf', bbox_inches='tight', pad_inches=0.1)
#plt.savefig('PPT/MTI_tau_spectrum.svg', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# #### **Induced Pairing**

# %%
# shape of the matrix 
n = 4

# space dimensions
K = []; Z = []
k_dim = 100; z_dim = 100

# read file pairing
rows = np.loadtxt("Pairing/pairing_tau_-1.txt")

# store data in matrices
F_data = np.empty((k_dim, z_dim, 4, 4), dtype='complex')


# loop over momenta
for idx in range(k_dim):
    
    # loop over space
    for jdx in range(z_dim):

        # index for rows
        irow = z_dim * idx + jdx
                
        # read one row
        row = rows[irow]
    
        if jdx == 0: K.append(float(row[0]))
    
        if idx == 0: Z.append(float(row[1]))
    
        # real part
        real = row[2 : 2 + n*n].reshape((n, n))
        # imaginary part
        imag = row[2 + n*n :].reshape((n, n))
        # pairing matrix
        matrix = real + 1j * imag

        F_data[idx][jdx] = Change_Basis(matrix)

print(F_data.shape)
# Out:
# (100, 100, 4, 4)

# %%
# norm of the induced pairing
F = np.linalg.norm(F_data, axis=(2,3))

contour = plt.contourf(F.T, levels=100)
plt.colorbar(contour)

y_ticks = np.linspace(0, len(Z)-1, 5)
y_labels = np.linspace(Z[0], Z[-1], 5)

x_ticks = np.linspace(0, len(K)-1, 5)
x_labels = np.linspace(K[0], K[-1], 5)


plt.xticks(x_ticks, x_labels);
plt.yticks(y_ticks, y_labels);

plt.xlabel('k')
plt.ylabel('z [$\AA$]');

# %% [markdown]
# ### **Spin Symmetry**

# %%
# swap spin only
F_swap = np.array([[Block_Reverse(f) for f in F1] for F1 in F_data])

# matrices for signlet
F_singlet = 0.5*(F_data - F_swap)
# matrices for triplet
F_triplet = 0.5*(F_data + F_swap)

fs = np.linalg.norm(F_singlet, axis=(2, 3))
ft = np.linalg.norm(F_triplet, axis=(2, 3))
norm = np.max(fs+ft)

print(fs.shape, ft.shape)
# Out:
# (100, 100) (100, 100)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

# First contour plot
c1 = axes[0].contourf(fs.T/norm, levels=np.linspace(0,1, 100),  cmap='magma_r', vmin=0, vmax=1)
fig.colorbar(c1, ax=axes[0])
axes[0].set_title('singlet')

# Second contour plot
c2 = axes[1].contourf(ft.T/norm, levels=np.linspace(0,1, 100), cmap='magma_r', vmin=0, vmax=1)
fig.colorbar(c2, ax=axes[1])
axes[1].set_title('triplet')

for ax in axes:
    ax.set_xticks(x_ticks, x_labels);
    ax.set_yticks(y_ticks, y_labels);


plt.tight_layout()
plt.show()

# %%
norm = np.sum(fs+ft, axis=0)[0]

plt.plot(np.sum(ft, axis=0)/norm, lw=3, label='triplet')
plt.plot(np.sum(fs, axis=0)/norm, lw=3, label='singlet')

plt.xticks(y_ticks, y_labels);
plt.legend();

#plt.savefig('PPT/tau_-1_spin_symm.pdf', bbox_inches='tight', pad_inches=0.1)
#plt.savefig('PPT/tau_-1_spin_symm.svg', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# #### **Triplet Components**

# %%
# spin S=0 part
F0 = 1./np.sqrt(2)*F_triplet[:, :, 0:2, 2:4]; f0 = np.linalg.norm(F0, axis=(2, 3))
# spin S=1 part
Fp1 = F_triplet[:, :, 0:2, 0:2]; fp1 = np.linalg.norm(Fp1, axis=(2, 3))
# spin S=-1 part
Fm1 = F_triplet[:, :, 2:4, 2:4]; fm1 = np.linalg.norm(Fm1, axis=(2, 3))

norm = np.max(f0+fp1+fm1)

fig, axes = plt.subplots(1, 3, figsize=(10, 4))  # 1 row, 2 columns

# First contour plot
c1 = axes[0].contourf(f0.T/norm, cmap='magma_r', levels=np.linspace(0,1, 100),)
fig.colorbar(c1, ax=axes[0])
axes[0].set_title('$S=0$')

# Second contour plot
c2 = axes[1].contourf(fp1.T/norm, cmap='magma_r', levels=np.linspace(0,1, 100),)
fig.colorbar(c2, ax=axes[1])
axes[1].set_title('$S=1$')

# Third contour plot
c3 = axes[2].contourf(fm1.T/norm, cmap='magma_r', levels=np.linspace(0,1, 100),)
fig.colorbar(c3, ax=axes[2])
axes[2].set_title('$S=-1$')


x_ticks = np.linspace(0, len(K)-1, 3)
x_labels = np.linspace(K[0], K[-1], 3)

for ax in axes:
    ax.set_xticks(x_ticks, x_labels);
    ax.set_yticks(y_ticks, y_labels);
    
plt.tight_layout()
plt.show()

# %%
norm = np.sum(f0+fp1+fm1, axis=0)[0]

plt.plot(np.sum(f0, axis=0)/norm, lw=3, label='$S=0$')
plt.plot(np.sum(fp1, axis=0)/norm, lw=3, label='$S=1$')
plt.plot(np.sum(fm1, axis=0)/norm, lw=3, label='$S=-1$')

plt.xticks(y_ticks, y_labels);

plt.legend();

#plt.savefig('PPT/tau_-1_spin_comp.pdf', bbox_inches='tight', pad_inches=0.1)
#plt.savefig('PPT/tau_-1_spin_comp.svg', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ### **Momentum Symmetry**

# %%
# reverse momentum
F_krev = F_data[::-1, :, :, :]

# matrices for even components
F_even = 0.5*(F_data + F_krev)
# matrices for odd components
F_odd = 0.5*(F_data - F_krev)

fe = np.linalg.norm(F_even, axis=(2, 3))
fo = np.linalg.norm(F_odd, axis=(2, 3))
norm = np.max(fe+fo)

print(fs.shape, ft.shape)
# Out:
# (100, 100) (100, 100)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

# First contour plot
c1 = axes[0].contourf(fe.T/norm, levels=np.linspace(0,1, 100),  cmap='magma_r', vmin=0, vmax=1)
fig.colorbar(c1, ax=axes[0])
axes[0].set_title('even')

# Second contour plot
c2 = axes[1].contourf(fo.T/norm, levels=np.linspace(0,1, 100), cmap='magma_r', vmin=0, vmax=1)
fig.colorbar(c2, ax=axes[1])
axes[1].set_title('odd')


for ax in axes:
    ax.set_xticks(x_ticks, x_labels);
    ax.set_yticks(y_ticks, y_labels);


plt.tight_layout()
plt.show()

# %%
norm = np.sum(fe+fo, axis=0)[0]

plt.plot(np.sum(fe, axis=0)/norm, lw=3, label='even')
plt.plot(np.sum(fo, axis=0)/norm, lw=3, label='odd')

plt.xticks(y_ticks, y_labels);
plt.legend();

#plt.savefig('PPT/tau_-1_mom_symm.pdf', bbox_inches='tight', pad_inches=0.1)
#plt.savefig('PPT/tau_-1_mom_symm.svg', bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# ### **Frequency Symmetry**

# %%
# shape of the matrix 
n = 4

# space dimensions
E = []; Z = []
e_dim = 100; z_dim = 100

# read file pairing
rows = np.loadtxt("Pairing/avgk/avgk_pairing_tau_-1.txt")

# store data in matrices
F_avgk = np.empty((e_dim, z_dim, 4, 4), dtype='complex')


# loop over energies
for idx in range(e_dim):
    
    # loop over space
    for jdx in range(z_dim):

        # index for rows
        irow = z_dim * idx + jdx
                
        # read one row
        row = rows[irow]
    
        if jdx == 0: E.append(float(row[0]))
    
        if idx == 0: Z.append(float(row[1]))
    
        # real part
        real = row[2 : 2 + n*n].reshape((n, n))
        # imaginary part
        imag = row[2 + n*n :].reshape((n, n))
        # pairing matrix
        matrix = real + 1j * imag

        F_avgk[idx][jdx] = Change_Basis(matrix)

print(F_avgk.shape)
# Out:
# (100, 100, 4, 4)

# %%
# reverse energy
F_wrev = F_avgk[::-1, :, :, :]

# matrices for even components
F_even_w = 0.5*(F_avgk + F_wrev)
# matrices for odd components
F_odd_w = 0.5*(F_avgk - F_wrev)

fe_w = np.linalg.norm(F_even_w, axis=(2, 3))
fo_w = np.linalg.norm(F_odd_w, axis=(2, 3))
norm = np.max(fe_w+fo_w)

print(fe_w.shape, fo_w.shape)
# Out:
# (100, 100) (100, 100)

# %%
norm = np.sum(fe_w+fo_w, axis=0)[0]

plt.plot(np.sum(fe_w, axis=0)/norm, lw=3, label='even', c='c')
plt.plot(np.sum(fo_w, axis=0)/norm, lw=3, label='odd', c='r')


y_ticks = np.linspace(0, len(Z)-1, 5)
y_labels = np.round(np.linspace(Z[0], Z[-1], 5),3)

plt.xticks(y_ticks, y_labels);
plt.legend();
