# %% [markdown]
# # BCS Hamiltonian
#
# We start here from the fully translational invariant BCS Hamiltonian which can be written as
# $$
# \begin{split}
#     H_{BCS} &= H_0 + V =
#     \int d\mathbf{k} \,
#     \left( \frac{\hbar^2 k^2}{2 m} - \mu \right)
#     \left(
#     \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow}
#     \hat{\phi}_{\mathbf{k} \, \uparrow}
#     +
#     \hat{\phi}^\dagger_{\mathbf{k} \, \downarrow}
#     \hat{\phi}_{\mathbf{k} \, \downarrow}
#     \right)
#     +
#     \int d \mathbf{k} \,
#     \left\lbrack
#     \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow}
#     \Delta_{\uparrow\downarrow}
#     \hat{\phi}^\dagger_{-\mathbf{k} \, \downarrow}
#     +
#     \hat{\phi}_{\mathbf{k} \, \uparrow}
#     \Delta^\star_{\downarrow\uparrow}
#     \hat{\phi}_{-\mathbf{k} \, \downarrow}
#     \right\rbrack
#     \,,
# \end{split}
# $$
# where $\hat{\phi}_{\mathbf{k} \, \sigma}$, $\left( \hat{\phi}^\dagger_{\mathbf{k} \, \sigma} \right)$ annihilates (creates) an electron with momentum $\mathbf{k} = (k_x,k_y,k_z)$ and spin $\sigma=\uparrow, \downarrow$.
# To diagonalize the Hamiltonian is convenient to introduce the Nambu basis defined as
# $$
#     \Phi_\mathbf{k} =
#     \begin{pmatrix}
#         \hat{\phi}_{\mathbf{k} \, \uparrow} \\[5pt]
#         \hat{\phi}^\dagger_{\mathbf{-k} \, \downarrow}
#     \end{pmatrix} \,,
#     \qquad
#     \Phi^\dagger_\mathbf{k} =
#     \begin{pmatrix}
#         \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} & \hat{\phi}_{\mathbf{-k} \, \downarrow}
#     \end{pmatrix} \,.
# $$
# These spinors enable us to unify the kinetic and pairing energy terms into a single vector field.
# The kinetic energy term can be written as
# $$
# \begin{split}
#     H_0 &=
#     \int d\mathbf{k} \,
#     \begin{pmatrix}
#         \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} & \hat{\phi}_{\mathbf{-k} \, \downarrow}
#     \end{pmatrix}
#     \begin{pmatrix}
#         \varepsilon_\mathbf{k} & 0 \\[5pt]
#         0 & -\varepsilon_\mathbf{k}
#     \end{pmatrix}
#     \begin{pmatrix}
#         \hat{\phi}_{\mathbf{k} \, \uparrow} \\[5pt]
#         \hat{\phi}^\dagger_{\mathbf{-k} \, \downarrow}
#     \end{pmatrix} = \\[5pt]
#     %%%
#     &=
#     \int d\mathbf{k} \,
#     \varepsilon_\mathbf{k}
#     \Bigl(
#     \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} \hat{\phi}_{\mathbf{k} \, \uparrow}
#     -
#     \hat{\phi}_{\mathbf{-k} \, \downarrow} \hat{\phi}^\dagger_{\mathbf{-k} \, \downarrow}
#     \Bigr) =\\[5pt]
#     %%%
#     &=
#     \int d\mathbf{k} \,
#     \varepsilon_\mathbf{k}
#     \Bigl(
#     \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} \hat{\phi}_{\mathbf{k} \, \uparrow}
#     +
#     \hat{\phi}^\dagger_{\mathbf{-k} \, \downarrow} \hat{\phi}_{\mathbf{-k} \, \downarrow}
#     - 1
#     \Bigr) = \\[5pt]
#     %%%
#     &=
#     \int d\mathbf{k} \,
#     \varepsilon_\mathbf{k}
#     \Bigl(
#     \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} \hat{\phi}_{\mathbf{k} \, \uparrow}
#     +
#     \hat{\phi}^\dagger_{\mathbf{-k} \, \downarrow} \hat{\phi}_{\mathbf{-k} \, \downarrow}
#     \Bigr)
#     - \int d\mathbf{k} \,
#     \varepsilon_\mathbf{k} \,,
# \end{split}
# $$
# we used the anticommutation relation between fermionic field operators
# $$
# \begin{equation}
#     \{ \hat{\phi}_{\mathbf{k} \, \sigma}, \hat{\phi}_{\mathbf{k'} \, \sigma'} \}
#     =
#     \{ \hat{\phi}_{\mathbf{k} \, \sigma}^\dagger, \hat{\phi}_{\mathbf{k'} \, \sigma'}^\dagger \}
#     = 0 \,,
#     \qquad
#     \{ \hat{\phi}_{\mathbf{k} \, \sigma}^\dagger, \hat{\phi}_{\mathbf{k'} \, \sigma'} \}
#     =
#     \{ \hat{\phi}_{\mathbf{k} \, \sigma}^\dagger, \hat{\phi}_{\mathbf{k'} \, \sigma'} \}
#     = \delta_{\sigma\sigma'}\delta_{\mathbf{k k'}} \,.
# \end{equation}
# $$ is given by  $\varepsilon_{\mathbf{k}} = \frac{\hbar^2}{2m} \left( k_x^2+k_y^2+k_z^2 \right)$, the first integral in the previous equation can be rewritten as
# $$
# \begin{split}
#     \int d\mathbf{k} \,
#     \varepsilon_\mathbf{k}
#     \Bigl(
#     \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} \hat{\phi}_{\mathbf{k} \, \uparrow}
#     +
#     \varepsilon_\mathbf{k}
#     \hat{\phi}^\dagger_{\mathbf{-k} \, \downarrow} \hat{\phi}_{\mathbf{-k} \, \downarrow}
#     \Bigr)
#     &=
#     \int d\mathbf{k} \,
#     \varepsilon_\mathbf{k}
#     \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} \hat{\phi}_{\mathbf{k} \, \uparrow}
#     +
#     \int d\mathbf{k} \,
#     \varepsilon_\mathbf{-k}
#     \hat{\phi}^\dagger_{\mathbf{k} \, \downarrow} \hat{\phi}_{\mathbf{k} \, \downarrow}
#     %%%
#     =
#     \int d\mathbf{k} \,
#     \varepsilon_\mathbf{k}
#     \Bigl(
#     \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} \hat{\phi}_{\mathbf{k} \, \uparrow}
#     +
#     \hat{\phi}^\dagger_{\mathbf{k} \, \downarrow} \hat{\phi}_{\mathbf{k} \, \downarrow}
#     \Bigr) \,,
# \end{split}
# $$
# where in the second term we renamed $\mathbf k \rightarrow \mathbf{-k}$ and we observed that $\varepsilon_\mathbf k = \varepsilon_\mathbf{-k}$.
# Therefore, for the kinetic energy we finally obtain
# $$
# \begin{split}
#     H_0 &=
#     \int d\mathbf{k} \,
#     \begin{pmatrix}
#         \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} & \hat{\phi}_{\mathbf{-k} \, \downarrow}
#     \end{pmatrix}
#     \begin{pmatrix}
#         \varepsilon_\mathbf{k} & 0 \\[5pt]
#         0 & -\varepsilon_\mathbf{k}
#     \end{pmatrix}
#     \begin{pmatrix}
#         \hat{\phi}_{\mathbf{k} \, \uparrow} \\[5pt]
#         \hat{\phi}^\dagger_{\mathbf{-k} \, \downarrow}
#     \end{pmatrix} = \\[5pt]
#     %%%
#     &=
#     \int d\mathbf{k} \,
#     \varepsilon_\mathbf{k}
#     \Bigl(
#     \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} \hat{\phi}_{\mathbf{k} \, \uparrow}
#     +
#     \hat{\phi}^\dagger_{\mathbf{k} \, \downarrow} \hat{\phi}_{\mathbf{k} \, \downarrow}
#     \Bigr)
#     -
#     \int d\mathbf{k} \,
#     \varepsilon_\mathbf{k} \,.
# \end{split}
# $$
#
#
#
#
# Similarly, the pairing term can be rewritten through the Nambu spinor as
# $$
# \begin{split}
#     V &= \int d\mathbf{k} \,
#     \begin{pmatrix}
#         \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} & \hat{\phi}_{\mathbf{-k} \, \downarrow}
#     \end{pmatrix}
#     \begin{pmatrix}
#         0 &  \Delta_{\uparrow\downarrow}  \\[5pt]
#         \Delta_{\uparrow\downarrow} ^\star & 0
#     \end{pmatrix}
#     \begin{pmatrix}
#         \hat{\phi}_{\mathbf{k} \, \uparrow} \\[5pt]
#         \hat{\phi}^\dagger_{\mathbf{-k} \, \downarrow}
#     \end{pmatrix} = \\[5pt]
#     %%%
#     &=
#     \int d\mathbf{k} \,
#     \Delta_{\uparrow\downarrow}
#     \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} \hat{\phi}^\dagger_{\mathbf{-k} \, \downarrow}
#     +
#     \Delta_{\uparrow\downarrow}^\star
#     \hat{\phi}_{\mathbf{-k} \, \downarrow} \hat{\phi}_{\mathbf{k} \, \uparrow}
#     = \\[5pt]
#     %%%
#     &=
#     \int d\mathbf{k} \,
#     \Delta_{\uparrow\downarrow}
#     \hat{\phi}^\dagger_{\mathbf{k} \, \uparrow} \hat{\phi}^\dagger_{\mathbf{-k} \, \downarrow}
#     +
#     \Delta_{\downarrow\uparrow}^\star \hat{\phi}_{\mathbf{k} \, \uparrow} \hat{\phi}_{\mathbf{-k} \, \downarrow} \,,
# \end{split}
# $$
# where we used the symmetry of the pairing potential $\Delta_{\uparrow\downarrow} = -\Delta_{\downarrow\uparrow}$ and the anticommutation of the field operators.
# Redefining $\Delta_{\uparrow\downarrow} \equiv \Delta$ and neglecting the constant term $\int d\mathbf{k} \, \epsilon_\mathbf{k}$ corresponding to the ground-state energy, the BCS Hamiltonian can be written as
# $$
#     H_{BCS} =
#     \int d\mathbf{k} \,
#     \Psi_{\mathbf{k}}^\dagger
#     \mathcal{h}_\mathbf{k}
#     \Psi_{\mathbf{k}} \,,
#     \qquad
#     \mathcal{h}_\mathbf{k} =
#     \begin{pmatrix}
#         \varepsilon_{\mathbf{k}} &  \Delta  \\[5pt]
#         \Delta^\star & -\varepsilon_{\mathbf{k}}
#     \end{pmatrix} \,.
# $$

# %%
import numpy as np
from numpy.linalg import eigh

# Pauli matrices in particle-hole space
tauX = np.array([[0, 1], [1, 0]])
tauY = np.array([[0, -1j], [1j, 0]])
tauZ = np.array([[1, 0], [0, -1]])

# function which compute the BCS spectrum numerically
def BCS_spectrum(kx, ky, kz, mu, Delta, t = 1.):

    # kinetic energy
    ek = t*(kx**2+ky**2+kz**2)-mu
    # BCS Hamiltonian
    hk = np.array([[ek, Delta], [np.conj(Delta), -ek]])

    return eigh(hk)


# function which computes the BCS spectrum analitycally
def BCS_spectrum_analytical(kx, ky, kz, mu, Delta, t = 1.):

    # energy
    ek = t*(kx**2+ky**2+kz**2)-mu; Ek =np.sqrt(ek**2+abs(Delta)**2)
    # eigenvalues
    return np.array([Ek, -Ek])

# %% [markdown]
# The energy spectrum of the BCS Hamiltonian can thus be found straightforwardly by diagonalizing $\mathcal{h}_\mathbf{k}$.
# Explicitly, eigenstates and eigenenergies of the conventional superconductor are given by
# $$
#     E_k = \pm \sqrt{\varepsilon_\mathbf{k}^2 + |\Delta|^2}  \,,
#     \qquad
#     \Phi_\mathbf k =
#     \frac{|\Delta|}{\sqrt{2\varepsilon_\mathbf k \left( \varepsilon_\mathbf k \pm E_k \right) }}
#     \begin{pmatrix}
#         \frac{1}{\Delta^\star} \Bigl( \varepsilon_\mathbf k \pm E_k \Bigr) \\[5pt]
#         1
#     \end{pmatrix} \,.
# $$
# The two components of the Nambu spinor $\Phi_k \equiv \bigl( u_k \; v_k \bigr)^T$ can be identified as electron $u_k$ and hole $v_k$ components of the quasiparticle excitations in the superconductor.
# For each eigenstate we can thus define a particle-hole character as the expectation value of the $\tau_z$ Pauli matrix acting in the Nambu space $\left\langle \Phi^\dagger_\mathbf{k} \, \tau_z \, \Phi_\mathbf{k} \right\rangle$.

# %%
# parameters
Delta = 0.05; mu = 0.1
# wavenumbers
K = np.concatenate( (np.linspace(-0.5, -0.3, 150), np.linspace(-0.3, 0.3, 150), np.linspace(0.3, 0.5, 150)) )

Nene = []; Negv = []; Nph = []
SCene = []; SCegv = []; SCph = []

# loop over wavenumbers
for k in K:
    
    # SC spectrum
    e, psi = BCS_spectrum(kx=k, ky=0., kz=0., mu=mu, Delta=Delta)
    
    # particle-hole character
    ph = [np.vdot(psi[:,i], np.dot(tauZ,psi[:,i])) for i in range(len(e))] 
    # append energies and eigenstates
    SCene.append(e); SCegv.append(psi); SCph.append(ph)

    # Normal spectrum
    e, psi = BCS_spectrum(kx=k, ky=0., kz=0., mu=mu, Delta=0.)
    # particle-hole character
    ph = [np.vdot(psi[:,i], np.dot(tauZ,psi[:,i])) for i in range(len(e))]
    # append energies and eigenstates
    Nene.append(e); Negv.append(psi); Nph.append(ph)

Nene = np.array(Nene); Negv = np.array(Negv); Nph = np.array(Nph)
SCene = np.array(SCene); SCegv = np.array(SCegv); SCph = np.array(SCph)

# spectrum analytically
SCene_analytical = np.array([BCS_spectrum_analytical(kx=k, ky=0., kz=0., mu=mu, Delta=Delta) for k in K])

# %% [markdown]
# #### <font color='green'> **Eigenstates and Eigenvalues** </font>
# We plot here the energy spectrum of the BCS superconductor, computed diagonalizing numerically the BCS Hamiltonian $\mathcal{h}_\mathbf{k}$ for a given wavenumber $k = |\mathbf k|$.

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
 
# figure
fig, ax = plt.subplots(1,2, figsize=(18,7))
# normalize colors 
norm = plt.Normalize(-1,1); cmap = plt.cm.jet #cmap = plt.cm.RdYlBu

# energy gap
ax[0].axhline(y=Delta, c='black', ls='dashed', lw=2); ax[0].axhline(y=-Delta, c='black', ls='dashed', lw=2);

for iegv in range(2):

    # plot as small segments
    for i in range(len(K) - 1):        
        # plot SC spectrum        
        ax[0].plot(K[i:i+2], SCene[:,iegv][i:i+2], color=cmap(norm(SCph[:,iegv][i])), linewidth=4)
        # plot Normal spectrum        
        #ax[0].plot(K[i:i+2], Nene[:,iegv][i:i+2], color=cmap(norm(Nph[:,iegv][i])), linewidth=2)

        ax[1].plot(K[i:i+2], [np.vdot(e[0],e[0]) for e in SCegv[:,iegv]][i:i+2], lw=4, color=cmap(norm(SCph[:,iegv][i])))
        ax[1].plot(K[i:i+2], [np.vdot(e[1],e[1]) for e in SCegv[:,iegv]][i:i+2], lw=4, color=cmap(norm(SCph[:,iegv][i])))

# Add a color bar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

#ax[0].set_title('BCS spectrum', fontsize = 13)
ax[0].set_xlabel("$k$", fontsize = 24)
ax[0].set_ylabel("$E_k$", fontsize = 24)
ax[0].tick_params(axis='both', which='major', labelsize=18)
#plt.colorbar(sm, ax=ax[0], ticks=[-1, -0.5, 0, 0.5, 1])

ax[1].set_xlabel("$k$", fontsize = 24)
ax[1].set_ylabel("$|u_k|^2$, $|v_k|^2$", fontsize = 24)
ax[1].tick_params(axis='both', which='major', labelsize=18)
cb = plt.colorbar(sm, ax=ax[1], ticks=[-1, -0.5, 0, 0.5, 1]);
cb.ax.tick_params(labelsize=18)

# %% [markdown]
# # BCS Green's Function
#
# We compute here the unperturbed Green's function in the BCS superconductor solving the Gor'kov equation which couples normal and anomlous propagator in the SC.
#
# ## **Gor'kov Equation**
#
# #### **Derivation**
#
# We recall here the definitions of the normal and anomalous time-ordered Green's functions in real time
# $$
#     \newcommand{\T}{\hat{T}_t \,}
#     %
# 	\mathcal{G}^{(0)}_{\sigma\sigma'}(zt,z't') =
# 	-i \left\langle
# 	\T \hat{\phi}_{\sigma}(zt) \hat{\phi}^\dagger_{\sigma'}(z't')
# 	\right\rangle_0 \,,
#     \qquad
# 	\mathcal{F}^{\dagger \, (0)}_{\sigma\sigma'}(zt,z't') =
# 	-i \left\langle
# 	\T \hat{\phi}^\dagger_{\sigma}(zt) \hat{\phi}^\dagger_{\sigma'}(z't')
# 	\right\rangle_0 \,,
#  $$
# where $\hat{\phi}^\dagger_{\sigma}(zt)$ $(\hat{\phi}_{\sigma}(zt))$ creates (annihilates) an electron with spin $\sigma$ in the SC at position $z$ and time $t$.
# As usual, we assume translational invariance along $x$ and $y$ amd we omit the indices for the in-plane wavenumbers $k_x$ and $k_y$.
# Here we derive the equations in real space $z$, even tough we will solve them in momentum space assuming translational invariance and neglecting finite size effect due to the interface between SC and MTI.
#
# Writing explicitly the action of the time-ordering operator, the normal Green's function becomes
# $$
#     \mathcal{G}^{(0)}_{\sigma\sigma'}(zt,z't') =
# 	-i \theta(t-t') \left\langle
# 	\hat{\phi}_{\sigma}(zt) \hat{\phi}^\dagger_{\sigma'}(z't')
# 	\right\rangle_0
#     +
#     i \theta(t'-t) \left\langle
# 	\hat{\phi}^\dagger_{\sigma'}(z't') \hat{\phi}_{\sigma}(zt)
# 	\right\rangle_0 \,,
# $$
# and the time derivative can be easily evaluated as
# $$
# \begin{split}
#     \partial_t \mathcal{G}^{(0)}_{\sigma\sigma'}(zt,z't') &=
#     -i \delta(t-t') \left\langle
# 	\left\{ \hat{\phi}^\dagger_{\sigma}(zt) , \hat{\phi}_{\sigma'}(z't') \right\}
# 	\right\rangle_0
#     -
#     i \left\langle
#     \T
# 	\partial_t \hat{\phi}_{\sigma}(zt) \hat{\phi}^\dagger_{\sigma'}(z't')
# 	\right\rangle_0 = \\[5pt]
#     %%%
#     &=
#     -i \delta_{\sigma\sigma'} \delta(z-z') \delta(t-t')
#     -
#     i \left\langle
#     \T
# 	\partial_t \hat{\phi}_{\sigma}(zt) \hat{\phi}^\dagger_{\sigma'}(z't')
# 	\right\rangle_0 \,.
# \end{split}
# $$
# In analogous way, for the anomalous Green's function we have that
# $$
#     \partial_t \mathcal{F}^{\dagger \, (0)}_{\sigma\sigma'}(zt,z't')
#     =
#     -i \left\langle
#     \T \partial_t \hat{\phi}^\dagger_{\sigma}(zt) \hat{\phi}^\dagger_{\sigma'}(z't')
# 	\right\rangle_0 \,,
# $$
# where the anticommutator between creation field operators is always vanishing.
# The time-derivative of $\hat{\phi}_{\sigma}(zt)$ and $\hat{\phi}^\dagger_{\sigma}(zt)$ in the Heisenberg picture is reduced to the commutator between the Hamiltonian and the field operators
# $$
# \begin{split}
#     \partial_t \hat{\phi}_{\sigma}(zt) =
#     \frac{i}{\hbar} \left\lbrack H, \hat{\phi}_{\sigma}(zt) \right\rbrack
#     &=
#     \frac{i}{\hbar} e^{\frac{i}{\hbar}Ht}
#     \left\lbrack H, \hat{\phi}_{\sigma}(z) \right\rbrack
#     e^{-\frac{i}{\hbar}Ht} \,, \\[5pt]
#     %%
#     \partial_t \hat{\phi}^\dagger_{\sigma}(zt) =
#     \frac{i}{\hbar} \left\lbrack H, \hat{\phi}^\dagger_{\sigma}(zt) \right\rbrack
#     &=
#     \frac{i}{\hbar} e^{\frac{i}{\hbar}Ht}
#     \left\lbrack H, \hat{\phi}^\dagger_{\sigma}(z) \right\rbrack
#     e^{-\frac{i}{\hbar}Ht} \,,
#     \end{split}
# $$
# which can be easily evaluated as
# $$
# \begin{split}
#     \left\lbrack H, \hat{\phi}_{\sigma}(z) \right\rbrack
#     &=
#     -h_{\sigma\sigma} \hat{\phi}_{\sigma}(z)
#     -
#     \sum_{\sigma'} \Delta_{\sigma\sigma'} \hat{\phi}^\dagger_{\sigma'}(z) \,, \\[5pt]
#     %%%
#     \left\lbrack H, \hat{\phi}^\dagger_{\sigma}(z) \right\rbrack
#     &=
#     h_{\sigma\sigma} \hat{\phi}^\dagger_{\sigma}(z)
#     -
#     \sum_{\sigma'} \Delta^\dagger_{\sigma\sigma'} \hat{\phi}_{\sigma'}(z) \,,
# \end{split}
# $$
# where $h_{\sigma\sigma}(k_x,k_y,k_z) = \varepsilon_\mathbf k - \mu$ is the diagonal matrix element of the kinetic energy which becomes a differential operator in real space $h_{\sigma\sigma}(-i\partial_z) \equiv h_{\sigma\sigma}(k_x,k_y,-i\partial_z)$, and we denote $\Delta^\dagger_{\sigma\sigma'} \equiv \Delta^\star_{\sigma'\sigma}$.
# The time-derivatives of the annihilation field operator is thus given by
# $$
# \begin{split}
#     \partial_t \hat{\phi}_{\sigma}(zt)
#     &=
#     \frac{i}{\hbar} e^{\frac{i}{\hbar}Ht}
#     \left\lbrack H, \hat{\phi}_{\sigma}(z) \right\rbrack
#     e^{-\frac{i}{\hbar}Ht} = \\[5pt]
#     %%%
#     &=
#     -\frac{i}{\hbar} e^{\frac{i}{\hbar}Ht}
#     \sum_{\sigma'}
#     \Bigl(
#     \delta_{\sigma\sigma'} h_{\sigma\sigma}(-i\partial_z) \hat{\phi}_{\sigma'}(z)
#     +
#     \Delta_{\sigma\sigma'} \hat{\phi}^\dagger_{\sigma'}(z)
#     \Bigr) e^{-\frac{i}{\hbar}Ht} = \\[5pt]
#     %%%
#     &=
#     -\frac{i}{\hbar}
#     \sum_{\sigma'}
#     \Bigl(
#     \delta_{\sigma\sigma'} h_{\sigma\sigma}(-i\partial_z) \hat{\phi}_{\sigma'}(zt)
#     +
#     \Delta_{\sigma\sigma'} \hat{\phi}^\dagger_{\sigma'}(zt)
#     \Bigr) \,,
# \end{split}
# $$
# where in the last row we used the definition of time-evolved operators in Heisenberg picture
# $$
#     \hat{\phi}_{\sigma}(zt) =  e^{\frac{i}{\hbar}Ht} \hat{\phi}_{\sigma}(z) e^{-\frac{i}{\hbar}Ht} \,,
#     \qquad
#     \hat{\phi}^\dagger_{\sigma}(zt) =  e^{\frac{i}{\hbar}Ht} \hat{\phi}^\dagger_{\sigma}(z) e^{-\frac{i}{\hbar}Ht} \,.
# $$
# Dealing in a similar way with the creation operator we get
# $$
# \begin{split}
#     %%
#     \partial_t \hat{\phi}^\dagger_{\sigma}(zt)
#     &=
#     \frac{i}{\hbar} e^{\frac{i}{\hbar}Ht}
#     \left\lbrack H, \hat{\phi}^\dagger_{\sigma}(z) \right\rbrack
#     e^{-\frac{i}{\hbar}Ht} = \\[5pt]
#     %%%
#     &=
#     \frac{i}{\hbar}
#     \sum_{\sigma'}
#     \Bigl(
#     \delta_{\sigma\sigma'} h_{\sigma\sigma}(-i\partial_z) \hat{\phi}^\dagger_{\sigma'}(zt)
#     -
#     \Delta^\dagger_{\sigma\sigma'} \hat{\phi}_{\sigma'}(zt)
#     \Bigr) \,.
# \end{split}
# $$

# %% [markdown]
# Plugging these expression into the equations for the time derivative of $\mathcal{G}^{(0)}_{\sigma\sigma'}(zt,z't')$ and $\mathcal{F}^{\dagger \, (0)}_{\sigma\sigma'}(zt,z't')$, we finally obtain the Gor'kov equation coupling normal and anomalous propagators:
#
# ---
# - i. **Normal Green's Function** \
#   For the normal Green's function we have
# $$
# \begin{split}
#     \partial_t \mathcal{G}^{(0)}_{\sigma\sigma'}(zt,z't')
#     &=
#     -i \delta_{\sigma\sigma'} \delta(z-z') \delta(t-t')
#     -
#     i \left\langle
#     \T
# 	\partial_t \hat{\phi}_{\sigma}(zt) \hat{\phi}^\dagger_{\sigma'}(z't')
# 	\right\rangle_0 = \\[5pt]
#     %%%
#     &=
#     -i \delta_{\sigma\sigma'} \delta(z-z') \delta(t-t')
#     - \frac{1}{\hbar} \sum_{\sigma''}
#     \Biggl(
#     h_{\sigma\sigma''}(-i\partial_z)
#     \left\langle \T \hat{\phi}_{\sigma''}(zt) \hat{\phi}^\dagger_{\sigma'}(z't') \right\rangle_0
#     +
#     \Delta_{\sigma\sigma''}
#     \left\langle \T \hat{\phi}^\dagger_{\sigma''}(zt) \hat{\phi}^\dagger_{\sigma'}(z't') \right\rangle_0
#     \Biggr) = \\[5pt]
#     %%%
#     &=
#     -i \delta_{\sigma\sigma'} \delta(z-z') \delta(t-t')
#     - \frac{i}{\hbar} \sum_{\sigma''}
#     \Biggl(
#     h_{\sigma\sigma''}(-i\partial_z)
#     \mathcal{G}^{(0)}_{\sigma''\sigma'}(zt,z't')
#     +
#     \Delta_{\sigma\sigma''}
#     \mathcal{F}^{\dagger \, (0)}_{\sigma''\sigma'}(zt,z't')
#     \Biggr) \,,
# \end{split}
# $$
# where we denoted $h_{\sigma\sigma''}(-i\partial_z) \equiv \delta_{\sigma\sigma''} h_{\sigma\sigma}(-i\partial_z)$.
# Using a matrix notation the previous equation can be rewritten as
# $$
#     \partial_t \mathcal{G}^{(0)}_{S}(zt,z't')
#     =
#     -i \delta(z-z') \delta(t-t')
#     - \frac{i}{\hbar}
#     \Biggl(
#     h_{0}(-i\partial_z)
#     \mathcal{G}^{(0)}_{S}(zt,z't')
#     +
#     \Delta
#     \mathcal{F}^{\dagger \, (0)}_{S}(zt,z't')
#     \Biggr) \,,
# $$
# and with some further manipulation we finally obtain
# $$
# \begin{split}
#     \Bigl( i \hbar \partial_t - h_{0}(-i\partial_z) \Bigr) \mathcal{G}^{(0)}_{S}(zt,z't')
#     -
#     \Delta \mathcal{F}^{\dagger \, (0)}_{S}(zt,z't')
#     =
#     \hbar \delta(z-z') \delta(t-t')
#     \,,
# \end{split}
# $$
# Since the Hamiltonian does not depend explicitly on time $\mathcal{G}^{(0)}_{S}(zt,z't') \equiv \mathcal{G}^{(0)}_{S}(z,z';t-t')$ and we can Fourier transform to frequency space through
# $$
#     \mathcal{G}^{(0)}_{S}(z,z';t-t') =
#     \int \frac{d\omega}{2\pi} \, e^{-i\omega(t-t')} \mathcal{G}^{(0)}_{S}(z,z';\omega) \,,
# $$
# such that the time derivative becomes algebraic
# $$
#     \partial_t \mathcal{G}^{(0)}_{S}(z,z';t-t') =
#     \int \frac{d\omega}{2\pi} \, (-i\omega) e^{-i\omega(t-t')} \mathcal{G}^{(0)}_{S}(z,z';\omega) \,,
# $$
# and the previous equation can be rewritten as
# $$
#   \boxed{
#   \Bigl( \hbar\omega - h_{0}(-i\partial_z) \Bigr) \mathcal{G}^{(0)}_{S}(z,z';\omega)
#     -
#     \Delta \mathcal{F}^{\dagger \, (0)}_{S}(z,z';\omega)
#     =
#     \hbar \delta(z-z')
#   }\,.
# $$
#
#
# ---
# - ii. **Anomalous Green's Function** \
#   Proceeding in a similar way, we can obtain an analogous equation for the anomalous Green's function
#   $$
#   \begin{split}
#     \partial_t \mathcal{F}^{\dagger \, (0)}_{\sigma\sigma'}(zt,z't')
#     &=
#     -i \left\langle
#     \T \partial_t \hat{\phi}^\dagger_{\sigma}(zt) \hat{\phi}^\dagger_{\sigma'}(z't')
#     \right\rangle_0 = \\[5pt]
#     %%%
#     &=
#     \frac{1}{\hbar}
#     \sum_{\sigma''} \Biggl(
#     h_{\sigma\sigma''}(-i\partial_z)
#     \left\langle \T
#     \hat{\phi}^\dagger_{\sigma''}(zt) \hat{\phi}^\dagger_{\sigma'}(z't')
#     \right\rangle_0
#     -
#     \Delta^\dagger_{\sigma\sigma''}
#     \left\langle \T
#     \hat{\phi}_{\sigma''}(zt) \hat{\phi}^\dagger_{\sigma'}(z't')
#     \right\rangle_0
#     \Biggr) = \\[5pt]
#     %%%
#     &=
#     \frac{i}{\hbar}
#     \Biggl(
#     h_{\sigma\sigma''}(-i\partial_z)
#     \mathcal{F}_{\sigma''\sigma'}^{\dagger \, (0)}(zt,z't')
#     -
#     \Delta^\dagger_{\sigma\sigma''}
#     \mathcal{G}_{\sigma''\sigma'}^{(0)}(zt,z't')
#     \Biggr) \,.
#   \end{split}
#   $$
#   Using matrix notation the previous equation reads as
#   $$
#     \partial_t \mathcal{F}^{\dagger \, (0)}_{S}(zt,z't')
#     =
#     \frac{i}{\hbar}
#     \Biggl(
#     h_{0}(-i\partial_z)
#     \mathcal{F}_{S}^{\dagger \, (0)}(zt,z't')
#     -
#     \Delta^\dagger
#     \mathcal{G}_{S}^{(0)}(zt,z't')
#     \Biggr) \,,
#   $$
#   and with some further manipulation we obtain
#   $$
#     \left( i\hbar \partial_t + h_{0}(-i\partial_z) \right)
#     \mathcal{F}^{\dagger \, (0)}_{S}(zt,z't')
#     -
#     \Delta^\dagger
#     \mathcal{G}_{S}^{(0)}(zt,z't') = 0 \,.
#   $$
#   Fourier transforming to frequency space, we finally get the following result
#   $$
#   \boxed{
#     \left( \hbar\omega + h_{0}(-i\partial_z) \right)
#     \mathcal{F}^{\dagger \, (0)}_{S}(z,z';\omega)
#     -
#     \Delta^\dagger
#     \mathcal{G}_{S}^{(0)}(z,z';\omega) = 0
#   } \,.
#   $$
#
#
# Therefore, in real space $z$, the Gor'kov equations coupling the (real) time-ordered normal and anomalous Green's functions takes the following form
# $$
#     \begin{gathered}
#     \Bigl( \hbar\omega - h_{0}(-i\partial_z) \Bigr) \mathcal{G}^{(0)}_{S}(z,z';\omega)
#     -
#     \Delta \mathcal{F}^{\dagger \, (0)}_{S}(z,z';\omega)
#     =
#     \hbar \delta(z-z') \,, \\[5pt]
#     %%%
#     \left( \hbar\omega + h_{0}(-i\partial_z) \right)
#     \mathcal{F}^{\dagger \, (0)}_{S}(z,z';\omega)
#     -
#     \Delta^\dagger
#     \mathcal{G}_{S}^{(0)}(z,z';\omega) = 0 \,.
#     \end{gathered}
# $$
# Assuming translational invariance even along the out-of-plane coordinate $z$ and neglecting finitee size effects due to the  interface with the MTI, we can Fourier transform to real space through
# $$
#     \begin{split}
# 	\mathcal{G}^{(0)}_S(z,z';\omega) &\equiv \mathcal{G}^{(0)}_S(z-z';\omega)
#     =
# 	\int \frac{d k_z}{2\pi} \, e^{i k_z (z-z')} \mathcal{G}^{(0)}_S(k_z;\omega) \,, \\[5pt]
#     %%%
# 	\mathcal{F}^{\dagger \, (0)}_S(z,z';\omega) &\equiv \mathcal{F}^{\dagger \, (0)}_S(z-z';\omega)
#     =
# 	\int \frac{d k_z}{2\pi} \, e^{i k_z (z-z')} \mathcal{F}^{\dagger \, (0)}_S(k_z;\omega) \,,
#     \end{split}
# $$
# such that the Gor'kov equations become algebraic in momentum space
# $$
#     \begin{gathered}
#     \Bigl( \hbar\omega - h_{0}(\mathbf{k}) \Bigr) \mathcal{G}^{(0)}_{S}(\mathbf{k};\omega)
#     -
#     \Delta \mathcal{F}^{\dagger \, (0)}_{S}(\mathbf{k};\omega)
#     =
#     \hbar \,, \\[5pt]
#     %%%
#     \left( \hbar\omega + h_{0}(\mathbf{k}) \right)
#     \mathcal{F}^{\dagger \, (0)}_{S}(\mathbf{k};\omega)
#     -
#     \Delta^\dagger
#     \mathcal{G}_{S}^{(0)}(\mathbf{k};\omega) = 0 \,.
#     \end{gathered}
# $$
# The momentum space representation of kinetic energy $h_0$ and the SC pairing field $\Delta$ are given by
# $$
#     h_0(\mathbf k) =
#     \begin{pmatrix}
#     \varepsilon_\mathbf k & 0 \\[5pt]
#     0 & \varepsilon_\mathbf k
#     \end{pmatrix} \,,
#     \qquad
#     \Delta = \Delta \sigma_y =
#     \begin{pmatrix}
#     0 & -i\Delta \\[5pt]
#     i\Delta & 0
#     \end{pmatrix} \,.
# $$

# %% [markdown]
# #### **Solution**
#
#
# In the basis of single particle states $\{ \ket{\uparrow}, \ket{\downarrow} \}$, the normal and anomalous Green's function matrices are given by
# $$
#     \mathcal{G}_{S}^{(0)} =
# 	\begin{bmatrix}
# 		g_{\uparrow\uparrow } & g_{\uparrow\downarrow} \\[5pt]
# 		%
# 		g_{\downarrow\uparrow} & g_{\downarrow\downarrow}
# 	\end{bmatrix} \,,
#     \qquad
#     \mathcal{F}_{S}^{\dagger \, (0)} =
# 	\begin{bmatrix}
# 		f_{\uparrow\uparrow}^\dagger & f_{\uparrow\downarrow}^\dagger \\[5pt]
# 		%
# 		f_{\downarrow\uparrow}^\dagger & f_{\downarrow\downarrow}^\dagger
# 	\end{bmatrix}
# $$
# In momentum space the coupled Gor'kov  equations can be immediately solved as
# $$
#     \mathcal{G}^{(0)}_{S}(\mathbf{k};\omega) = \hbar
#     \Bigl\lbrack
#     \left( \hbar\omega - h_0 \right)
#     -
#     \Delta \left( \hbar\omega + h_0 \right)^{-1} \Delta^\dagger
#     \Bigr\rbrack^{-1} \,,
#     \qquad
#     \mathcal{F}^{\dagger \, (0)}_{S}(\mathbf{k};\omega) =
#     \left( \hbar\omega + h_0 \right)^{-1} \Delta^\dagger
#     \mathcal{G}^{(0)}_{S}(\mathbf{k};\omega) \,,
# $$
# which yields the following explicitly result
# $$
#     \mathcal{G}_S^{(0)} =
#     \frac{\hbar}{(\hbar \omega)^2 - E_k^2}
#     \begin{bmatrix}
#         \hbar\omega + \varepsilon_k & 0 \\[5pt]
#         0 & \hbar\omega + \varepsilon_k
#     \end{bmatrix} \,,
#     \qquad
#     \mathcal{F}^{\dagger \, (0)}_S =
#     \frac{i \hbar}{(\hbar \omega)^2 - E_k^2}
#     \begin{bmatrix}
#         0 & - \Delta^\star \\[5pt]
#         \Delta^\star & 0
#     \end{bmatrix} \,,
# $$
# where $E_k=\sqrt{\varepsilon_k^2+|\Delta|^2}$ is the quasiparticle excitation energy in the superconductor.
# Consistently with the assumption of a conventional $s$-wave pairing, the off-diagonal (diagonal) part of the normal (anomalous) propagator vanishes
# $$
#     \mathcal{g}_{\uparrow\downarrow} = \mathcal{g}_{\downarrow\uparrow} = 0 \,,
#     \qquad
#     \mathcal{f}^\dagger_{\uparrow\uparrow} = \mathcal{f}^\dagger_{\downarrow\downarrow} = 0 \,,
# $$
# while the nontrivial components are explicitly given by
# $$
#     \mathcal{g}_{\uparrow\uparrow} = \mathcal{g}_{\downarrow\downarrow} =
#     \frac{\hbar( \hbar\omega + \varepsilon_k)}{(\hbar \omega)^2 - E_k^2} \,,
#     \qquad
#     \mathcal{f}^\dagger_{\uparrow\downarrow} = -\mathcal{f}^\dagger_{\downarrow\uparrow} =
#     -\frac{i \hbar \Delta^\star}{(\hbar \omega)^2 - E_k^2} \,.
# $$
#
#
#
#
# While the previous equations describe the bulk of a translational invariant superconductor, we are ultimately interested in the characterization of the pairing induced in the topological insulator.
# For this purpose, we need to transform back to real space and express $\mathcal{G}_S$ and $\mathcal{F}_S^\dagger$ as functions of the out-of-plane coordinate $z-z'$.
# Recalling the Fourier transform from momentum to real space, we need to evaluate the following integrals
# $$
# \begin{split}
# 	\mathcal{G}^{(0)}_S(z,z') &\equiv \mathcal{G}^{(0)}_S(z-z') =
# 	\int \frac{d k_z}{2\pi} \, e^{i k_z (z-z')} \mathcal{G}^{(0)}_S(k_z) \,, \\[5pt]
#      %%%
# 	\mathcal{F}^{\dagger \, (0)}_S(z,z') &\equiv \mathcal{F}^{\dagger \, (0)}_S(z-z') =
# 	\int \frac{d k_z}{2\pi} \, e^{i k_z (z-z')} \mathcal{F}^{\dagger \, (0)}_S(k_z) \,,
# \end{split}
# $$
# where we dropped the indices for the in-plane wavenumber $k_x$ and $k_y$.
# Both integrals can be computed using contour integration in the complex plane.

# %% [markdown]
# #### <font> **Poles** </font>
#
# We can observe that both normal and anomalous Green's function share the same poles, which are given by the zeros of the denominator $(\hbar \omega)^2 - E_k^2 =  0$.
# With some straightforward algebra, the 4 poles of the integrand functions can be written as
# $$
#     \boxed{k_p = \pm i \sqrt{\frac{1}{t} (\varepsilon_0 \pm \omega_0)}} \,,
# $$
# where $t=\frac{\hbar^2}{2m}$, $\varepsilon_0 = t(k_x^2+k_y^2)-\mu$ and $\omega_0 = \sqrt{(\hbar\omega)^2-|\Delta|^2}$.
# It is important to note that the order  and the position of the poles in the complex plane depend on the energy $\hbar \omega$.

# %%
# Function defining the poles 
def poles(kx, ky, omega, Delta, mu, t = 1., hbar = 1.):
 
    e0 = t*(kx**2+ky**2)-mu

    w0 = np.sqrt( complex((hbar*omega)**2 - np.abs(Delta)**2) )

    return np.multiply( np.sqrt([1./t*(e0+w0), 1./t*(e0+w0), 1./t*(e0-w0), 1./t*(e0-w0)]), [-1j,1j,-1j,1j])

# %% [markdown]
# In order to study the induced proximity effect, we are interested in tunnelling of electrons with energy below the SC gap $\Delta$, i.e. we restrict ourselves to the range of frequencies $-|\Delta| < \hbar \omega < |\Delta|$.
# In this conditions we have that
#   $$
#   \omega_0 = \sqrt{(\hbar \omega)^2-|\Delta|^2} = i \sqrt{|\Delta|^2-(\hbar \omega)^2} \,,
#   $$
# is always a purely imaginary number.
# In order to understand the distribution of the poles on the complex plane, the square root $\sqrt{\frac{1}{t} (\varepsilon_0 \pm \omega_0)}$ can be evaluated explicitly and the poles can be rewritten as
# $$
#     k_1 = \xi_- - i\xi_+ \,,
#     \qquad
#     k_2 = -\xi_- + i\xi_+ \,,
#     \qquad
#     k_3 = -\xi_- - i\xi_+ \,,
#     \qquad
#     k_4 = \xi_- + i\xi_+ \,,
# $$
# where
# $$
#       \xi_\pm = \sqrt{\frac{1}{2t} \left( \sqrt{E_0^2-(\hbar \omega)^2} \pm \varepsilon_0 \right)} \,,
#       \qquad
#       E_0 = \sqrt{\varepsilon_0^2 + |\Delta|^2} \,.
# $$
# In this way, it is clear that the poles are complex with nonzero real and imaginary parts, and they lie on the circumference of radius $|k_p| = \frac{1}{t} \sqrt{E_0^2 - (\hbar \omega)^2}$, centred in the origin.
#
#
#
# #### <font color='green'> **Poles** </font>
# Below, the four poles $k_p$ of the integrand function are plotted in the complex plane for energies $0 \leq \hbar \omega \leq |\Delta|$.

# %%
# parameters
kx = 0.073; ky = 0.081; Delta = 0.05; e0 = kx**2+ky**2; E0 = np.sqrt(e0**2+np.abs(Delta)**2); mu = 0.023
# energies 
Nene = 100; omega = np.linspace(0., Delta, Nene)
# compute poles +mu
kp = np.array([poles(kx, ky, w, Delta, mu) for w in omega])
# compute poles -mu
kpminus = np.array([poles(kx, ky, w, Delta, -mu) for w in omega])

# figure
fig, ax = plt.subplots(1,2, figsize=(22,7.5))
# color map
cmap = 'viridis'

ax[0].axvline(x=0, c='black', lw=0.5); ax[0].axhline(y=0, c='black', lw=0.5)
ax[1].axvline(x=0, c='black', lw=0.5); ax[1].axhline(y=0, c='black', lw=0.5)
# loop over poles
for ipole in range(4):
    # plot ploes on complex plane
    s = ax[0].scatter(kp[:,ipole].real, kp[:,ipole].imag, c=omega, cmap=cmap, s=50);

    ax[1].scatter(kpminus[:,ipole].real, kpminus[:,ipole].imag, c=omega, cmap=cmap, s=50);
    


# poles at Delta gap +mu
#kpDelta = poles(kx, ky, Delta, Delta, mu)
#ax[0].scatter(kpDelta.real, kpDelta.imag, c='red', s=50)

# poles at Delta gap -mu
#kpDelta = poles(kx, ky, Delta, Delta, -mu)
#ax[1].scatter(kpDelta.real, kpDelta.imag, c='red', s=50)


# labels ax[0]
ax[0].set_xlabel('$\Re (k_p)$', fontsize = 26)
ax[0].set_ylabel('$\Im (k_p)$', fontsize = 26);
ax[0].tick_params(axis='both', which='major', labelsize=20);

# labels ax[1]
ax[1].set_xlabel('$\Re (k_p)$', fontsize = 26)
ax[1].tick_params(axis='both', which='major', labelsize=20);

sm = plt.cm.ScalarMappable(cmap=cmap)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax)
cbar.ax.tick_params(labelsize=20)
cbar.set_label('$\hbar \omega/\Delta$', fontsize=26)

print(e0-mu, e0+mu)
# Out:
# -0.01111 0.03489

# %% [markdown]
# #### **Contour Integrals**
#
# In all that follows we rename $k_z \equiv k$ in order to simplify the notation.
# Assuming a complex momentum $k = k_r + i k_i$, the above integrals can be evaluated in the complex plane through the residue theorem if the exponential factor
# $$
# 	e^{i k(z-z')} = e^{i k_r(z-z')} e^{-k_i (z-z')} \,,
# $$
# converges in in the limit of large $k_i$.
# For $k_i>0$, we have
# $$
# 	\lim_{k_i \rightarrow +\infty} e^{-k_i (z-z')} =
# 	\begin{cases}
# 		0 & \text{if} \quad z-z' \geq 0 \,, \\[5pt]
# 		+ \infty  & \text{if} \quad z-z' < 0 \,,
# 	\end{cases}
# $$
# and conversely for $k_i<0$
# $$
# 	\lim_{k_i \rightarrow -\infty} e^{-k_i (z-z')} =
# 	\begin{cases}
# 		+ \infty  & \text{if} \quad z-z' \geq 0 \,, \\[5pt]
# 		0 & \text{if} \quad z-z' < 0 \,,
# 	\end{cases}
# $$
# meaning that to ensure the convergence of the integrand function for large imaginary part of $k$ we need to choose a closed path in the upper half of the complex plane when $z-z' \geq 0$ or in the lower one when $z-z' < 0$.
#
# In general, the integral of a complex-valued function $f$ over a closed path $\gamma$ in the complex plane can be computed through the residue theorem as
# $$
# \oint_\gamma f(k) \, dk = 2\pi i \sum_j I(\gamma, k_j) \text{Res}(f,k_j) \,,
# $$
# where $k_j$ are the poles enclosed by $\gamma$, $\text{Res}(f,k_j)$ is the residue of the function $f$ in $k_j$ and $I(\gamma, k_j)$ is the winding number of $\gamma$ around $k_j$, whose sign is positive (negative) for an anticlockwise (clockwise) loop.
# If we choose as closed path the semicircle $C_R^\pm$ of radius $R$ lying in the upper (lower) half of the complex plane, the integral can be decomposed as
# $$
# 	\oint f(k) \, dk =
# 	\int_{-R}^R dk \, f(k) +
# 	\int_{C_R^\pm} dk \, f(k) \,.
# $$
# If in the limit of large $|z|$ the integrand function decays at least as $|f(z)| \sim 1/|z|^a$ for $a>1$, then by Jordan's lemma we have that
# $$
# 	\lim_{R \rightarrow +\infty} \int_{C_R^\pm} dk \, f(k) = 0 \,,
# $$
# and taking the limit $R \rightarrow +\infty$ we obtain
# $$
# 	\oint f(k) \, dk =
# 	\lim_{R \rightarrow \infty} \int_{-R}^R dk \, f(k) +
# 	\lim_{R \rightarrow \infty} \int_{C^\pm_R} dk \, f(k) =
# 	\int dk \, f(k) \,.
# $$
# Therefore, by means of residues theorem, the integral on the real axis can be computed as the sum of the residues enclosed by the loop
# $$
#     \int  \frac{dk}{2\pi} \, f(k) =
# 	\oint \frac{dk}{2\pi} \, f(k) =
# 	\pm i \sum_j \text{Res}(f,k_j) \,,
# $$
# where the positive (negative) sign is for the loop closed in the upper (lower) half-plane.
#
# For both normal and anomalous Green's function, the integral can be computed along the following paths in the limit of $R \rightarrow +\infty$.
# As discussed above, the blue path in the upper plane is valid for $z-z' \geq 0$ while the red one in the lower plane is valid for $z-z' < 0$.
#
# <p style="text-align:center;">
# <img src="Path-integrals.png" width=50% height=50% class="center" />
# </p>
#
# ## **Normal Green's Function**
#
# The normal Green's function is explicitly given by
# $$
#     \mathcal{G}_{\sigma\sigma}^{(0)}(z-z', \omega) =
# 	\int \frac{d k}{2\pi} \, f(k) \,,
#     \qquad
#     f(k) \equiv
#     \frac{\hbar( \hbar\omega + \varepsilon_k)}{(\hbar \omega)^2 - E_k^2} \, e^{i k (z-z')}  \,.
# $$
# To perform the integration, we distinguish the following cases:
#
# ---
# - i. **Upper plane** \
#   For $z-z' \geq 0$ we select the loop closed in the upper half of the complex plane.
#   The integral can thus be evaluated as
#   $$
#       \int \frac{d k}{2\pi} \, f(k)
#       =
#       i \Bigl\lbrack \text{Res}(f,k_2) + \text{Res}(f,k_4) \Bigr\rbrack \,.
#   $$
#   Since all the poles are *simple* poles, the residues can be computed as
#   $$
#       \text{Res}(f,k_p) = \lim_{k \rightarrow k_p} (k - k_p) f(k) \,,
#   $$
#   yielding
#   $$
#   \text{Res}(f,k_2) =
#   \frac{\hbar (\hbar\omega-\omega_0)}{4t\omega_0} \frac{1}{k_+} e^{i k_+ (z-z')} \,,
#   \qquad
#   \text{Res}(f,k_4) =
#   -\frac{\hbar (\hbar\omega+\omega_0)}{4t\omega_0} \frac{1}{k_-} e^{i k_- (z-z')} \,,
#   $$
#   where we introduced a new notation for the poles $k_\pm = i \sqrt{\frac{1}{t}(\varepsilon_0 \pm \omega_0)}$.
#   Skipping some straightforward algebra, the integral can be evaluated as
#   $$
#       \int \frac{d k}{2\pi} \, f(k)
#       =
#       i \Bigl\lbrack \text{Res}(f,k_2) + \text{Res}(f,k_4) \Bigr\rbrack
#       =
#       \frac{i\hbar}{4t\omega_0}
#       \Biggl\lbrack
#       \frac{\Omega_-}{k_+} e^{i k_+ (z-z')} - \frac{\Omega_+}{k_-} e^{i k_- (z-z')}
#       \Biggr\rbrack \,,
#   $$
#   where we defined $\Omega_\pm = \hbar\omega \pm \omega_0$.
#
#   ---
# - ii. **Lower plane** \
#   For $z-z' < 0$ we select the loop closed in the lower half of the complex plane.
#   The integral can thus be evaluated as
#   $$
#       \int \frac{d k}{2\pi} \, f(k)
#       =
#       -i \Bigl\lbrack \text{Res}(f,k_1) + \text{Res}(f,k_3) \Bigr\rbrack \,.
#   $$
#   As previously, the residues are given by
#   $$
#   \text{Res}(f,k_1) =
#   \frac{\hbar (\hbar\omega-\omega_0)}{4t\omega_0} \frac{1}{k_+} e^{-i k_+ (z-z')} \,,
#   \qquad
#   \text{Res}(f,k_3) =
#   \frac{\hbar (\hbar\omega+\omega_0)}{4t\omega_0} \frac{1}{k_-} e^{-i k_- (z-z')} \,,
#   $$
#   and the integral can be evaluated as
#   $$
#       \int \frac{d k}{2\pi} \, f(k)
#       =
#       i \Bigl\lbrack \text{Res}(f,k_1) + \text{Res}(f,k_3) \Bigr\rbrack
#       =
#       \frac{i\hbar}{4t\omega_0}
#       \Biggl\lbrack
#       \frac{\Omega_-}{k_+} e^{-i k_+ (z-z')} - \frac{\Omega_+}{k_-} e^{-i k_- (z-z')}
#       \Biggr\rbrack \,.
#   $$
#
# The two results can be easily condensed in the following way:
#   $$
#     \mathcal{G}_{\sigma\sigma}^{(0)}(z-z', \omega) =
#     \int \frac{d k}{2\pi} \,
#     \frac{\hbar( \hbar\omega + \varepsilon_k)}{(\hbar \omega)^2 - E_k^2} \, e^{i k (z-z')}
#      =
#      \boxed{
#      \frac{i\hbar}{4t\omega_0}
#      \Biggl\lbrack
#      \frac{\Omega_-}{k_+} e^{i k_+ |z-z'|} - \frac{\Omega_+}{k_-} e^{i k_- |z-z'|}
#      \Biggr\rbrack
#      } \,.
#   $$

# %%
# function which computes the normal GF in the SC
def GFnormal(z, Z, kx, ky, mu, Delta, w, t = 1., hbar = 1.):
    
    # energy e0
    e0 = t*(kx**2+ky**2)-mu
    # frequency w0
    w0 = np.sqrt( complex((hbar*w)**2 - np.abs(Delta)**2) )
    
    # Omega plus/minus
    Wp = hbar*w + w0; Wm = hbar*w - w0
    # poles
    kp = 1j*np.sqrt((e0+w0)/t); km = 1j*np.sqrt((e0-w0)/t)

    return 1j*hbar/(4*t*w0) * ( Wm/kp * np.exp(1j*kp*np.abs(z-Z)) - Wp/km * np.exp(1j*km*np.abs(z-Z)) )

# %% [markdown]
# #### <font color='green'> **Plot** </font>
#
# We plot the Green's function $\mathcal{G}^{(0)}_{\sigma\sigma}(z-z',\omega)$ as a function of the energy $\hbar \omega$ of the electrons.

# %%
energies = np.linspace(-0.049, 0.049, 250)
# parameters
kx = 0.073; ky = 0.081; Delta = 0.05; mu = 0.025; z = 48.6
# Greens function
gf = np.array([GFnormal(z=z, Z=0., kx=kx, ky=ky, mu=mu, Delta=Delta, w=w, t = 1., hbar = 1.) for w in energies])


# figure
fig, ax = plt.subplots(figsize=(8, 6))
# plot normal GF
ax.plot(energies, gf.real, c='red', lw=2, label='real')
ax.plot(energies, gf.imag, c='black', lw=2, label='imaginary')
# energy gap
ax.axvline(x=Delta, c='black', ls='dashed'); ax.axvline(x=-Delta, c='black', ls='dashed')


ax.set_xlabel("$\hbar \omega$", fontsize = 17)
ax.set_ylabel("$\Re(\mathcal{G}_{\sigma\sigma})$" + "", fontsize = 17)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.legend(fontsize = 14);

# %% [markdown]
# ## **Anomalous Green's Function**
#
# The anomalous Green's function is explicitly given by
# $$
# 	\mathcal{F}^{\dagger \, (0)}_{\downarrow\uparrow}(z-z') =
# 	\int \frac{d k}{2\pi} \, g(k) \,,
#     \qquad
#     g(k) \equiv
#     \frac{i \hbar \Delta^\star}{(\hbar \omega)^2 - E_k^2} \, e^{i k (z-z')} \,,
# $$
# and the two off-diagonsal components are relate by $\mathcal{F}^{\dagger}_{\uparrow\downarrow} = - \mathcal{F}^{\dagger}_{\downarrow\uparrow}$.
# To perform the integration, we distinguish the following cases:
#
# ---
# - i. **Upper plane** \
#   For $z-z' \geq 0$ we select the loop closed in the upper half of the complex plane.
#   The integral can thus be evaluated as
#   $$
#       \int \frac{d k}{2\pi} \, g(k)
#       =
#       i \Bigl\lbrack \text{Res}(g,k_2) + \text{Res}(g,k_4) \Bigr\rbrack \,.
#   $$
#   As discussed above, the residues can be computed as
#   $$
#       \text{Res}(g,k_p) = \lim_{k \rightarrow k_p} (k - k_p) g(k) \,,
#   $$
#   yielding
#   $$
#   \text{Res}(g,k_2) =
#   \frac{i \hbar \Delta^\star}{4t\omega_0} \frac{e^{i k_+ (z-z')}}{k_+}  \,,
#   \qquad
#   \text{Res}(g,k_4) =
#   -\frac{i \hbar \Delta^\star}{4t\omega_0} \frac{e^{i k_- (z-z')}}{k_-} \,.
#   $$
#   Skipping some straightforward algebra, the integral can be evaluated as
#   $$
#       \int \frac{d k}{2\pi} \, g(k)
#       =
#       i \Bigl\lbrack \text{Res}(g,k_2) + \text{Res}(g,k_4) \Bigr\rbrack
#       =
#       -\frac{\hbar \Delta^\star}{4t\omega_0}
#       \Biggl\lbrack
#       \frac{e^{i k_+ (z-z')}}{k_+} - \frac{e^{i k_- (z-z')}}{k_-}
#       \Biggr\rbrack \,,
#   $$
#   where we defined $\Omega_\pm = \hbar\omega \pm \omega_0$.
#
#   ---
# - ii. **Lower plane** \
#   For $z-z' < 0$ we select the loop closed in the lower half of the complex plane.
#   The integral can thus be evaluated as
#   $$
#       \int \frac{d k}{2\pi} \, f(k)
#       =
#       -i \Bigl\lbrack \text{Res}(f,k_1) + \text{Res}(f,k_3) \Bigr\rbrack \,.
#   $$
#   The residues are given by
#   $$
#   \text{Res}(g,k_1) =
#   -\frac{i \hbar \Delta^\star}{4t\omega_0} \frac{e^{i k_+ (z-z')}}{k_+}  \,,
#   \qquad
#   \text{Res}(g,k_3) =
#   \frac{i \hbar \Delta^\star}{4t\omega_0} \frac{e^{i k_- (z-z')}}{k_-} \,,
#   $$
#   and the integral can be evaluated as
#   $$
#       \int \frac{d k}{2\pi} \, g(k)
#       =
#       -i \Bigl\lbrack \text{Res}(g,k_1) + \text{Res}(g,k_3) \Bigr\rbrack
#       =
#       -\frac{\hbar \Delta^\star}{4t\omega_0}
#       \Biggl\lbrack
#       \frac{e^{-i k_+ (z-z')}}{k_+}  - \frac{e^{-i k_- (z-z')}}{k_-}
#       \Biggr\rbrack \,.
#   $$
#
# The two results can be easily condensed in the following way:
#   $$
#     \mathcal{F}^{\dagger \, (0)}_{\downarrow\uparrow}(z-z') =
#     \int \frac{d k}{2\pi} \,
#     \frac{i \hbar \Delta^\star}{(\hbar \omega)^2 - E_k^2} \, e^{i k_z (z-z')}
#      =
#      \boxed{
#      -\frac{\hbar \Delta^\star}{4t\omega_0}
#       \Biggl\lbrack
#       \frac{e^{i k_+ |z-z'|}}{k_+} - \frac{e^{i k_- |z-z'|}}{k_-}
#       \Biggr\rbrack
#      } \,.
#   $$

# %%
# function which computes the anomalous GF in the SC
def GFanomalous(z, Z, kx, ky, mu, Delta, w, t = 1., hbar = 1.):
    
    # energy e0
    e0 = t*(kx**2+ky**2)-mu
    # frequency w0
    w0 = np.sqrt( complex((hbar*w)**2 - np.abs(Delta)**2) )
    # poles
    kp = 1j*np.sqrt(1./t*(e0+w0)); km = 1j*np.sqrt(1./t*(e0-w0))

    return -hbar*np.conj(Delta)/(4*t*w0) * ( 1./kp*np.exp(1j*kp*np.abs(z-Z)) - 1./km*np.exp(1j*km*np.abs(z-Z)) )

# %% [markdown]
# #### <font color='green'> **Plot** </font>
#
#
# We plot the anomalous Green's function $\mathcal{F}^{\dagger \, (0)}_{\downarrow\uparrow}(z-z',\omega)$ as a function of the energy $\hbar \omega$ of the electrons.

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm


energies = np.linspace(-0.049, 0.049, 250)
# parameters
kx = 0.073; ky = 0.081; Delta = 0.05; mu = 0.025; z = 34.
# Greens function
gfa = np.array([GFanomalous(z=z, Z=0., kx=kx, ky=ky, mu=mu, Delta=Delta, w=w, t = 1., hbar = 1.) for w in energies])


# figure
fig, ax = plt.subplots(figsize=(8,6))
# plot normal GF
ax.plot(energies, gfa.real, c='red', lw=2, label='real')
ax.plot(energies, gfa.imag, c='black', lw=2, label='imaginary')
# energy gap
ax.axvline(x=Delta, c='black', ls='dashed'); ax.axvline(x=-Delta, c='black', ls='dashed')

ax.set_xlabel("$\hbar \omega$", fontsize = 17)
ax.set_ylabel("$\mathcal{F}^{\dagger \, (0)}_{\downarrow \\uparrow}$", fontsize = 17)
ax.tick_params(axis='both', which='major', labelsize=14) 
ax.legend(fontsize=14);

# %% [markdown]
# ## **Normal and Anomalous Propagators** </font>
# We plot here the normal and anomalous Green's functions together
#
#
# #### <font color='green'> **Energy Plot** </font>

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm


energies = np.linspace(-0.049, 0.049, 250)
# parameters
kx = 0.; ky = 0.; Delta = 0.05; mu = 0.025; z = 10.

# normal Greens function
gf = np.array([GFnormal(z=z, Z=0., kx=kx, ky=ky, mu=mu, Delta=Delta, w=w, t = 1., hbar = 1.) for w in energies])
# anomalous Greens function
gfa = np.array([GFanomalous(z=z, Z=0., kx=kx, ky=ky, mu=mu, Delta=Delta, w=w, t = 1., hbar = 1.) for w in energies])


# figure
fig, ax = plt.subplots(figsize=(10,6))
# plot normal and anomalous GF
ax.plot(energies, gf.real, c='red', lw=3, ls='-', label='$\Re \{ \mathcal{G}^{(0)}(0,\omega) \}$')
ax.plot(energies, gfa.imag, c='blue', lw=3, ls='-', label='$\Im \{ \mathcal{F}^{\dagger \, (0)}(0,\omega) \}$')
# energy gap
ax.axvline(x=Delta, c='black', ls='dashed', lw=1.5); ax.axvline(x=-Delta, c='black', ls='dashed', lw=1.5)

ax.set_xlabel("$\hbar \omega / \Delta$", fontsize = 20)
ax.set_xticks([-Delta, -Delta/2, 0, Delta/2, Delta], ['$-1$', '$-0.5$', '0', '$0.5$', '$1$'])
ax.set_ylabel("arb. un.", fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=16) 
ax.legend(fontsize=16);

# %% [markdown]
# #### <font color='green'> **Real-Space Plot** </font>

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm


space = np.linspace(-50.,50., 250)
# parameters
kx = 0.; ky = 0.; Delta = 0.05; mu = 0.025; w = 0.0025

# normal Greens function
gf = np.array([GFnormal(z=z, Z=0., kx=kx, ky=ky, mu=mu, Delta=Delta, w=w, t = 1., hbar = 1.) for z in space])
# anomalous Greens function
gfa = np.array([GFanomalous(z=z, Z=0., kx=kx, ky=ky, mu=mu, Delta=Delta, w=w, t = 1., hbar = 1.) for z in space])


# figure
fig, ax = plt.subplots(figsize=(10,6))

# plot normal GF
ax.plot(space, gf.real, c='red', lw=3, ls='-', label='$\Re \{ \mathcal{G}^{(0)}(z,\omega) \}$')
# plot anomalous GF
ax.plot(space, gfa.imag, c='blue', lw=3, ls='-', label='$\Im \{ \mathcal{F}^{\dagger \, (0)} (z,\omega) \}$')


ax.set_xlabel("$z$", fontsize = 20)
ax.set_ylabel("arb. un.", fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=16) 
ax.legend(fontsize=16, loc='lower right');
