# %% [markdown]
# # **Pairing Analysis**
#
# We start analysing the symmetry of the pairing with frequency and momentum for the different channels.

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Math, display

from Pairing_Projection import Pairing_Projection, Pairing_Channel, Symmetric_Components, Get_Symmetry_Channel, Get_Total_Component
from MTI_Second_Order import FMTI2_NeumannBC, FMTI2_Relative_Coordinates, FMTI2_Wigner_Transform, Change_Basis

# labels for curves
Flabels = [["$f_{\\uparrow +, \\uparrow +}$", "$f_{\\uparrow +, \downarrow +}$", "$f_{\\uparrow +, \\uparrow -}$", "$f_{\\uparrow +, \downarrow -}$"],
          ["$f_{\downarrow +, \\uparrow +}$", "$f_{\downarrow +, \downarrow +}$", "$f_{\downarrow +, \\uparrow -}$", "$f_{\downarrow +, \downarrow -}$"],
          ["$f_{\\uparrow -, \\uparrow +}$", "$f_{\\uparrow -, \downarrow +}$", "$f_{\\uparrow -, \\uparrow -}$", "$f_{\\uparrow -, \downarrow -}$"],
          ["$f_{\downarrow -, \\uparrow +}$", "$f_{\downarrow -, \downarrow +}$", "$f_{\downarrow -, \\uparrow -}$", "$f_{\downarrow -, \downarrow -}$"]]

# colors for plotting
colors_real = ['brown', 'red', 'orange', 'gold']
# colors for plotting
colors_imag = ['blue','dodgerblue','lightskyblue','cyan']
# colors for plotting
colors_abs = ["#0077FF", "#00CC00", "#FFD700", "#FF2200"]

# labels for projection
label_sigma = {
    '11':   r"\ket{ \uparrow\uparrow }",
    '22':   r"\ket{ \downarrow\downarrow }",
    'sym':  r"\ket{\uparrow\downarrow} + \ket{\downarrow\uparrow}",
    'asym': r"\ket{\uparrow\downarrow} - \ket{\downarrow\uparrow}"
}

# labels for projection
label_lambda = {
    '11':   r"\ket{++}",
    '22':   r"\ket{--}",
    'sym':  r"\ket{+-} + \ket{-+}",
    'asym': r"\ket{+-} - \ket{-+}"
}

ratio_label = ['even $\omega$, even $k$',
              'even $\omega$, odd $k$',
              'odd $\omega$, even $k$',
              'odd $\omega$, odd $k$',]

# %% [markdown]
# ### **Frequency and Momentum Symmetry**
#
# We evaluate the symmetry of the pairing with respect to both frequency and momentum for a given selected channel in spin and orbital space.

# %%
# parameters
d = 100.; mu = 0.010; Delta = 0.005; L = 0.0; omega = 0.; Z0 = 1.; k = 0.; kx = 0.001; ky = 0.001
# coupling matrices
Gamma = np.matrix([[1,0],[0,1],[1,0],[0,1]])


# compute symmetrized components of pairing
symm_pair = Symmetric_Components(d=d, Z0=Z0, k=k, kx=k, ky=k, L=L, mu=mu, Delta=Delta, omega=omega, Gamma=Gamma, N=19)

# define spin and orbital channel
spin='asym'; orbital='11'


symmetry = ['even frequency, even momentum',
           'even frequency, odd momentum',
           'odd frequency, even momentum',
           'odd frequency, odd momentum']
ratio = []
# loop over frequency symmetry
for freq in ['even','odd']:
    # loop over momentum symmetry
    for mom in ['even','odd']:
        
        # get total component for normalization
        f = Get_Total_Component(symm_pair, spin=spin, orbital=orbital)
        
        # get symmetry component
        f_sym = Get_Symmetry_Channel(symm_pair, frequency=freq, momentum=mom, spin=spin, orbital=orbital)

        # append to ratio array
        ratio.append(f_sym/f)

ratio = np.array(ratio)

# display the pairing channel
channel = rf"""
    \mathrm{{spin}}=\,{label_sigma[spin]}\,, 
    \quad
    \mathrm{{orbital}}={label_lambda[orbital]}
    """
display(Math(channel))

# print all symmetrized components for given channel 
for idx in range(4):
    print( symmetry[idx], ': ', round(abs(ratio[idx]),3) )
# Out:
# $\displaystyle
#     \mathrm{spin}=\,\ket{\uparrow\downarrow} - \ket{\downarrow\uparrow}\,,
#     \quad
#     \mathrm{orbital}=\ket{++}
#     $
# even frequency, even momentum :  1.0
# even frequency, odd momentum :  0.0
# odd frequency, even momentum :  0.0
# odd frequency, odd momentum :  0.0

# %% [markdown]
# ### **Spin Singlet $\ket{\uparrow\downarrow} - \ket{\downarrow\uparrow}$**
#
# We start evaluating the symmetry of the spin singlet state $\ket{\uparrow\downarrow} - \ket{\downarrow\uparrow}$ with frequency and momentum.
# For such a state there are 4 possible combinations with the orbital flavour.
#
# #### <font color='green'> **Orbital Singlet $\ket{+-} - \ket{-+}$** </font>
# We consider here the antisymmetric orbital state $\ket{+-} - \ket{-+}$. The total state is *symmetric* since it is given by
# $$
#     \Lambda_A =
#     \bigl( \ket{\uparrow\downarrow} - \ket{\downarrow\uparrow} \bigr)
#     \otimes
#     \bigl( \ket{+-} - \ket{-+} \bigr) \,.
# $$

# %%
from tqdm.notebook import tqdm

# parameters
mu = 0.010; Delta = 0.005; omega = 0.0025; Z0 = 1.; k = 0.001; kx = 0.001; ky = 0.001
# coupling matrices
Gamma = np.matrix([[1,0],[0,1],[1,0],[0,1]])

# define spin and orbital channel
spin='asym'; orbital='asym'

# Zeeman values 
Zeeman = np.linspace(-0.050, 0.050, 100)

ratio_asym_asym = []

# loop over Zeeman
for idx in tqdm(range(len(Zeeman)), desc="Processing"):

    # Zeeman field
    L = Zeeman[idx]
    # ratio for each component
    r = []
    
    # compute symmetrized components of pairing
    symm_pair = Symmetric_Components(d=d, Z0=Z0, k=k, kx=k, ky=k, L=L, mu=mu, Delta=Delta, omega=omega, Gamma=Gamma, N=19)
    
    # loop over frequency symmetry
    for freq in ['even','odd']:
        # loop over momentum symmetry
        for mom in ['even','odd']:
            
            # get total component for normalization
            f = Get_Total_Component(symm_pair, spin=spin, orbital=orbital)
            
            # get symmetry component
            f_sym = Get_Symmetry_Channel(symm_pair, frequency=freq, momentum=mom, spin=spin, orbital=orbital)
    
            # append to ratio array
            r.append(abs(f_sym/f))
    
    ratio_asym_asym.append(np.array(r))

ratio_asym_asym = np.array(ratio_asym_asym)
print(ratio_asym_asym.shape)
# Out:
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]
# (100, 4)

# %%
plt.style.use(['default', './paper.mplstyle'])

# figure
fig, ax = plt.subplots(1,1, figsize=(8,6))

for idx in range(4):

    ax.plot(Zeeman, ratio_asym_asym[:,idx], c=colors_abs[idx], label=ratio_label[idx], lw=4, ls='-')

#ax.set_ylabel("$f_{even,odd}$", fontsize = 14)
ax.set_xlabel("Zeeman $\Lambda$ [meV]", fontsize = 14)

#ax.set_title("spin singlet, orbital antisymmetric", fontsize=14)
ax.legend(fontsize=14);

#fig.savefig("Sasym_Lasym.pdf")

# %% [markdown]
# #### <font color='green'> **Orbital Triplet $\ket{+-} + \ket{-+}$** </font>
#
# We consider here the symmetric orbital state $\ket{+-} + \ket{-+}$. The total state is *antisymmetric* since it is given by
# $$
#     \Lambda_A =
#     \bigl( \ket{\uparrow\downarrow} - \ket{\downarrow\uparrow} \bigr)
#     \otimes
#     \bigl( \ket{+-} + \ket{-+} \bigr) \,.
# $$

# %%
# parameters
mu = 0.010; Delta = 0.005; omega = 0.0025; Z0 = 1.; k = 0.001; kx = 0.001; ky = 0.001
# coupling matrices
Gamma = np.matrix([[1,0],[0,1],[1,0],[0,1]])

# define spin and orbital channel
spin='asym'; orbital='sym'

# Zeeman values 
Zeeman = np.linspace(-0.050, 0.050, 100)

ratio_asym_sym = []

# loop over Zeeman
for idx in tqdm(range(len(Zeeman)), desc="Processing"):

    # Zeeman field
    L = Zeeman[idx]
    # ratio for each component
    r = []
    
    # compute symmetrized components of pairing
    symm_pair = Symmetric_Components(d=d, Z0=Z0, k=k, kx=k, ky=k, L=L, mu=mu, Delta=Delta, omega=omega, Gamma=Gamma, N=19)
    
    # loop over frequency symmetry
    for freq in ['even','odd']:
        # loop over momentum symmetry
        for mom in ['even','odd']:
            
            # get total component for normalization
            f = Get_Total_Component(symm_pair, spin=spin, orbital=orbital)
            
            # get symmetry component
            f_sym = Get_Symmetry_Channel(symm_pair, frequency=freq, momentum=mom, spin=spin, orbital=orbital)
    
            # append to ratio array
            r.append(abs(f_sym/f))
    
    ratio_asym_sym.append(np.array(r))

ratio_asym_sym = np.array(ratio_asym_sym)
print(ratio_asym_sym.shape)
# Out:
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]
# (100, 4)

# %%
# figure
fig, ax = plt.subplots(1,1, figsize=(8,6))

for idx in range(4):

    ax.plot(Zeeman, ratio_asym_sym[:,idx], c=colors_abs[idx], label=ratio_label[idx], lw=4, ls='-')

#ax.set_ylabel("$f_{even,odd}$", fontsize = 14)
ax.set_xlabel("Zeeman $\Lambda$ [meV]", fontsize = 14)

#ax.set_title("spin singlet, orbital symmetric", fontsize=14)
ax.legend(fontsize=14);

#fig.savefig("Sasym_Lsym.pdf")

# %% [markdown]
# ### **Spin Triplet $\ket{\uparrow\downarrow} + \ket{\downarrow\uparrow}$**
#
# We evaluate here the symmetry of the spin singlet state $\ket{\uparrow\downarrow} + \ket{\downarrow\uparrow}$ with frequency and momentum.
# For such a state there are 4 possible combinations with the orbital flavour.
#
# #### <font color='green'> **Orbital Singlet $\ket{+-} - \ket{-+}$** </font>
# We consider here the antisymmetric orbital state $\ket{+-} - \ket{-+}$. The total state is *antisymmetric* since it is given by
# $$
#     \Lambda_A =
#     \bigl( \ket{\uparrow\downarrow} + \ket{\downarrow\uparrow} \bigr)
#     \otimes
#     \bigl( \ket{+-} - \ket{-+} \bigr) \,.
# $$

# %%
# parameters
mu = 0.010; Delta = 0.005; omega = 0.0025; Z0 = 1.; k = 0.001; kx = 0.001; ky = 0.001
# coupling matrices
Gamma = np.matrix([[1,0],[0,1],[1,0],[0,1]])

# define spin and orbital channel
spin='sym'; orbital='asym'

# Zeeman values 
Zeeman = np.linspace(-0.050, 0.050, 100)

ratio_sym_asym = []

# loop over Zeeman
for idx in tqdm(range(len(Zeeman)), desc="Processing"):

    # Zeeman field
    L = Zeeman[idx]
    # ratio for each component
    r = []
    
    # compute symmetrized components of pairing
    symm_pair = Symmetric_Components(d=d, Z0=Z0, k=k, kx=k, ky=k, L=L, mu=mu, Delta=Delta, omega=omega, Gamma=Gamma, N=19)
    
    # loop over frequency symmetry
    for freq in ['even','odd']:
        # loop over momentum symmetry
        for mom in ['even','odd']:
            
            # get total component for normalization
            f = Get_Total_Component(symm_pair, spin=spin, orbital=orbital)
            
            # get symmetry component
            f_sym = Get_Symmetry_Channel(symm_pair, frequency=freq, momentum=mom, spin=spin, orbital=orbital)
    
            # append to ratio array
            r.append(abs(f_sym/f))
    
    ratio_sym_asym.append(np.array(r))

ratio_sym_asym = np.array(ratio_sym_asym)
print(ratio_sym_asym.shape)
# Out:
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]
# (100, 4)

# %%
# figure
fig, ax = plt.subplots(1,1, figsize=(8,6))

for idx in range(4):

    ax.plot(Zeeman, ratio_sym_asym[:,idx], c=colors_abs[idx], label=ratio_label[idx], lw=4, ls='-')

#ax.set_ylabel("$f_{even,odd}$", fontsize = 14)
ax.set_xlabel("Zeeman $\Lambda$ [meV]", fontsize = 14)

#ax.set_title("spin symmetric, orbital antisymmetric", fontsize=14)

ax.legend(fontsize=14);

#fig.savefig("Ssym_Lasym.pdf")

# %% [markdown]
# #### <font color='green'> **Orbital Triplet $\ket{+-} + \ket{-+}$** </font>
# We consider here the symmetric orbital state $\ket{+-} + \ket{-+}$. The total state is *symmetric* since it is given by
# $$
#     \Lambda_A =
#     \bigl( \ket{\uparrow\downarrow} + \ket{\downarrow\uparrow} \bigr)
#     \otimes
#     \bigl( \ket{+-} + \ket{-+} \bigr) \,.
# $$

# %%
# parameters
mu = 0.010; Delta = 0.005; omega = 0.0025; Z0 = 1.; k = 0.001; kx = 0.001; ky = 0.001
# coupling matrices
Gamma = np.matrix([[1,0],[0,1],[1,0],[0,1]])

# define spin and orbital channel
spin='sym'; orbital='sym'

# Zeeman values 
Zeeman = np.linspace(-0.050, 0.050, 100)

ratio_sym_sym = []

# loop over Zeeman
for idx in tqdm(range(len(Zeeman)), desc="Processing"):

    # Zeeman field
    L = Zeeman[idx]
    # ratio for each component
    r = []
    
    # compute symmetrized components of pairing
    symm_pair = Symmetric_Components(d=d, Z0=Z0, k=k, kx=k, ky=k, L=L, mu=mu, Delta=Delta, omega=omega, Gamma=Gamma, N=19)
    
    # loop over frequency symmetry
    for freq in ['even','odd']:
        # loop over momentum symmetry
        for mom in ['even','odd']:
            
            # get total component for normalization
            f = Get_Total_Component(symm_pair, spin=spin, orbital=orbital)
            
            # get symmetry component
            f_sym = Get_Symmetry_Channel(symm_pair, frequency=freq, momentum=mom, spin=spin, orbital=orbital)
    
            # append to ratio array
            r.append(abs(f_sym/f))
    
    ratio_sym_sym.append(np.array(r))

ratio_sym_sym = np.array(ratio_sym_sym)
print(ratio_sym_sym.shape)
# Out:
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]
# (100, 4)

# %%
# figure
fig, ax = plt.subplots(1,1, figsize=(8,6))

for idx in range(4):

    ax.plot(Zeeman, ratio_sym_sym[:,idx], c=colors_abs[idx], label=ratio_label[idx], lw=4, ls='-')

#ax.set_ylabel("$f_{even,odd}$", fontsize = 14)
ax.set_xlabel("Zeeman $\Lambda$ [meV]", fontsize = 14)

#ax.set_title("spin symmetric, orbital symmetric", fontsize=14)

ax.legend(fontsize=14);

#fig.savefig("Ssym_Lsym.pdf")

# %% [markdown]
# ### **Spin Triplet $\ket{\uparrow\uparrow}$**
#
# We evaluate here the symmetry of the spin singlet state $\ket{\uparrow\uparrow}$ with frequency and momentum.
# For such a state there are 4 possible combinations with the orbital flavour.
#
# #### <font color='green'> **Orbital Singlet $\ket{+-} - \ket{-+}$** </font>
# We consider here the antisymmetric orbital state $\ket{+-} - \ket{-+}$. The total state is *antisymmetric* since it is given by
# $$
#     \Lambda_A =
#     \ket{\uparrow\uparrow}
#     \otimes
#     \bigl( \ket{+-} - \ket{-+} \bigr) \,.
# $$

# %%
# parameters
mu = 0.010; Delta = 0.005; omega = 0.0025; Z0 = 1.; k = 0.001; kx = 0.001; ky = 0.001
# coupling matrices
Gamma = np.matrix([[1,0],[0,1],[1,0],[0,1]])

# define spin and orbital channel
spin='11'; orbital='asym'

# Zeeman values 
Zeeman = np.linspace(-0.050, 0.050, 100)

ratio_11_asym = []

# loop over Zeeman
for idx in tqdm(range(len(Zeeman)), desc="Processing"):

    # Zeeman field
    L = Zeeman[idx]
    # ratio for each component
    r = []
    
    # compute symmetrized components of pairing
    symm_pair = Symmetric_Components(d=d, Z0=Z0, k=k, kx=k, ky=k, L=L, mu=mu, Delta=Delta, omega=omega, Gamma=Gamma, N=19)
    
    # loop over frequency symmetry
    for freq in ['even','odd']:
        # loop over momentum symmetry
        for mom in ['even','odd']:
            
            # get total component for normalization
            f = Get_Total_Component(symm_pair, spin=spin, orbital=orbital)
            
            # get symmetry component
            f_sym = Get_Symmetry_Channel(symm_pair, frequency=freq, momentum=mom, spin=spin, orbital=orbital)
    
            # append to ratio array
            r.append(abs(f_sym/f))
    
    ratio_11_asym.append(np.array(r))

ratio_11_asym = np.array(ratio_11_asym)
print(ratio_11_asym.shape)
# Out:
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]
# (100, 4)

# %%
# figure
fig, ax = plt.subplots(1,1, figsize=(8,6))

for idx in range(4):

    ax.plot(Zeeman, ratio_11_asym[:,idx], c=colors_abs[idx], label=ratio_label[idx], lw=4, ls='-')

#ax.set_ylabel("$f_{even,odd}$", fontsize = 14)
ax.set_xlabel("Zeeman $\Lambda$ [meV]", fontsize = 14)

#ax.set_title("spin up-up, orbital antisymmetric", fontsize=14)

ax.legend(fontsize=14);

#fig.savefig("S11_Lasym.pdf")

# %% [markdown]
# #### <font color='green'> **Orbital Triplet $\ket{+-} + \ket{-+}$** </font>
# We consider here the antisymmetric orbital state $\ket{+-} + \ket{-+}$. The total state is *symmetric* since it is given by
# $$
#     \Lambda_A =
#     \ket{\uparrow\uparrow}
#     \otimes
#     \bigl( \ket{+-} + \ket{-+} \bigr) \,.
# $$

# %%
# parameters
mu = 0.010; Delta = 0.005; omega = 0.0025; Z0 = 0.; k = 0.001; kx = 0.001; ky = 0.001
# coupling matrices
Gamma = np.matrix([[1,0],[0,1],[1,0],[0,1]])

# define spin and orbital channel
spin='11'; orbital='sym'

# Zeeman values 
Zeeman = np.linspace(-0.050, 0.050, 100)

ratio_11_sym = []

# loop over Zeeman
for idx in tqdm(range(len(Zeeman)), desc="Processing"):

    # Zeeman field
    L = Zeeman[idx]
    # ratio for each component
    r = []
    
    # compute symmetrized components of pairing
    symm_pair = Symmetric_Components(d=d, Z0=Z0, k=k, kx=k, ky=k, L=L, mu=mu, Delta=Delta, omega=omega, Gamma=Gamma, N=19)
    
    # loop over frequency symmetry
    for freq in ['even','odd']:
        # loop over momentum symmetry
        for mom in ['even','odd']:
            
            # get total component for normalization
            f = Get_Total_Component(symm_pair, spin=spin, orbital=orbital)
            
            # get symmetry component
            f_sym = Get_Symmetry_Channel(symm_pair, frequency=freq, momentum=mom, spin=spin, orbital=orbital)
    
            # append to ratio array
            r.append(abs(f_sym/f))
    
    ratio_11_sym.append(np.array(r))

ratio_11_sym = np.array(ratio_11_sym)
print(ratio_11_sym.shape)
# Out:
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]
# (100, 4)

# %%
# figure
fig, ax = plt.subplots(1,1, figsize=(8,6))

for idx in range(4):

    ax.plot(Zeeman, ratio_11_sym[:,idx], c=colors_abs[idx], label=ratio_label[idx], lw=4, ls='-')

#ax.set_ylabel("$f_{even,odd}$", fontsize = 14)
ax.set_xlabel("Zeeman $\Lambda$ [meV]", fontsize = 14)

#ax.set_title("spin up-up, orbital symmetric", fontsize=14)

ax.legend(fontsize=14);

#fig.savefig("S11_Lsym.pdf")

# %% [markdown]
# ### **Spin Triplet $\ket{\downarrow\downarrow}$**
#
# We evaluate here the symmetry of the spin singlet state $\ket{\downarrow\downarrow}$ with frequency and momentum.
# For such a state there are 4 possible combinations with the orbital flavour.
#
# #### <font color='green'> **Orbital Singlet $\ket{+-} - \ket{-+}$** </font>
# We consider here the antisymmetric orbital state $\ket{+-} - \ket{-+}$. The total state is *antisymmetric* since it is given by
# $$
#     \Lambda_A =
#     \ket{\downarrow\downarrow}
#     \otimes
#     \bigl( \ket{+-} - \ket{-+} \bigr) \,.
# $$

# %%
# parameters
mu = 0.010; Delta = 0.005; omega = 0.0025; Z0 = 1.; k = 0.001; kx = 0.001; ky = 0.001
# coupling matrices
Gamma = np.matrix([[1,0],[0,1],[1,0],[0,1]])

# define spin and orbital channel
spin='22'; orbital='asym'

# Zeeman values 
Zeeman = np.linspace(-0.050, 0.050, 100)

ratio_22_asym = []

# loop over Zeeman
for idx in tqdm(range(len(Zeeman)), desc="Processing"):

    # Zeeman field
    L = Zeeman[idx]
    # ratio for each component
    r = []
    
    # compute symmetrized components of pairing
    symm_pair = Symmetric_Components(d=d, Z0=Z0, k=k, kx=k, ky=k, L=L, mu=mu, Delta=Delta, omega=omega, Gamma=Gamma, N=19)
    
    # loop over frequency symmetry
    for freq in ['even','odd']:
        # loop over momentum symmetry
        for mom in ['even','odd']:
            
            # get total component for normalization
            f = Get_Total_Component(symm_pair, spin=spin, orbital=orbital)
            
            # get symmetry component
            f_sym = Get_Symmetry_Channel(symm_pair, frequency=freq, momentum=mom, spin=spin, orbital=orbital)
    
            # append to ratio array
            r.append(abs(f_sym/f))
    
    ratio_22_asym.append(np.array(r))

ratio_22_asym = np.array(ratio_22_asym)
print(ratio_22_asym.shape)
# Out:
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]
# (100, 4)

# %%
# figure
fig, ax = plt.subplots(1,1, figsize=(8,6))

for idx in range(4):

    ax.plot(Zeeman, ratio_22_asym[:,idx], c=colors_abs[idx], label=ratio_label[idx], lw=4, ls='-')

#ax.set_ylabel("$f_{even,odd}$", fontsize = 14)
ax.set_xlabel("Zeeman $\Lambda$ [meV]", fontsize = 14)

#ax.set_title("spin dw-dw, orbital antisymmetric", fontsize=14)

ax.legend(fontsize=14);
#fig.savefig("S22_Lasym.pdf")

# %% [markdown]
# #### <font color='green'> **Orbital Singlet $\ket{+-} + \ket{-+}$** </font>
# We consider here the antisymmetric orbital state $\ket{+-} + \ket{-+}$. The total state is *antisymmetric* since it is given by
# $$
#     \Lambda_A =
#     \ket{\downarrow\downarrow}
#     \otimes
#     \bigl( \ket{+-} + \ket{-+} \bigr) \,.
# $$

# %%
# parameters
mu = 0.010; Delta = 0.005; omega = 0.0025; Z0 = 1.; k = 0.001; kx = 0.001; ky = 0.001
# coupling matrices
Gamma = np.matrix([[1,0],[0,1],[1,0],[0,1]])

# define spin and orbital channel
spin='22'; orbital='sym'

# Zeeman values 
Zeeman = np.linspace(-0.050, 0.050, 100)

ratio_22_sym = []

# loop over Zeeman
for idx in tqdm(range(len(Zeeman)), desc="Processing"):

    # Zeeman field
    L = Zeeman[idx]
    # ratio for each component
    r = []
    
    # compute symmetrized components of pairing
    symm_pair = Symmetric_Components(d=d, Z0=Z0, k=k, kx=k, ky=k, L=L, mu=mu, Delta=Delta, omega=omega, Gamma=Gamma, N=19)
    
    # loop over frequency symmetry
    for freq in ['even','odd']:
        # loop over momentum symmetry
        for mom in ['even','odd']:
            
            # get total component for normalization
            f = Get_Total_Component(symm_pair, spin=spin, orbital=orbital)
            
            # get symmetry component
            f_sym = Get_Symmetry_Channel(symm_pair, frequency=freq, momentum=mom, spin=spin, orbital=orbital)
    
            # append to ratio array
            r.append(abs(f_sym/f))
    
    ratio_22_sym.append(np.array(r))

ratio_22_sym = np.array(ratio_22_sym)
print(ratio_22_sym.shape)
# Out:
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]
# (100, 4)

# %%
# figure
fig, ax = plt.subplots(1,1, figsize=(8,6))

for idx in range(4):

    ax.plot(Zeeman, ratio_22_sym[:,idx], c=colors_abs[idx], label=ratio_label[idx], lw=4, ls='-')

#ax.set_ylabel("$f_{even,odd}$", fontsize = 14)
ax.set_xlabel("Zeeman $\Lambda$ [meV]", fontsize = 14)

#ax.set_title("spin dw-dw, orbital symmetric", fontsize=14)
ax.legend(fontsize=14);

fig.savefig("S22_Lsym.pdf")
